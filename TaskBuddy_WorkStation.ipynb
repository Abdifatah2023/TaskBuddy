# %% [markdown]
# ## Connect to Google Drive Mock Data

# %%
# !pip install -q -U langchain-google-genai langchain langchain-community PyPDF2
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pypdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pypdf in c:\users\abdif\appdata\roaming\python\python313\site-packages (6.7.1)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install chromadb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chromadb in c:\users\abdif\appdata\roaming\python\python313\site-packages (1.5.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (2.3.1)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (1.24.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (0.24.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.8.3)
# Requirement already satisfied: packaging>=24.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\abdif\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\abdif\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\abdif\appdata\roaming\python\python313\site-packages (from httpx>=0.27.0->chromadb) (4.12.1)
# Requirement already satisfied: httpcore==1.* in c:\users\abdif\appdata\roaming\python\python313\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\abdif\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in c:\users\abdif\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\abdif\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (6.32.0)
# Requirement already satisfied: sympy in c:\users\abdif\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from tokenizers>=0.13.2->chromadb) (1.4.1)
# Requirement already satisfied: filelock in c:\users\abdif\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\abdif\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\abdif\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in c:\users\abdif\appdata\roaming\python\python313\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipywidgets) (9.3.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\abdif\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\abdif\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\abdif\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
import os


# 2. Define your Mock Data path (Update 'MyProjectFolder' to your actual folder name)
mock_data_path = r"C:\Users\abdif\OneDrive\Documents\TaskBuddy\Syllabi\Syllabus.pdf"

# 3. List files to verify the agent can "see" them
# files = os.listdir(mock_data_path)
# print(f"Found {len(files)} documents: {files}")

# %% [markdown]
# ## Basic AI Agent Set up

# %%
from dotenv import load_dotenv

load_dotenv()


# It's best practice to store keys in Colab "Secrets" (the key icon on the left)
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-preview-09-2025")

# %%
from langchain_community.document_loaders import PyPDFLoader

# Initialize the loader with the path to your PDF file
loader = PyPDFLoader(mock_data_path)

# Load the documents (each page is a separate Document object)
pages = loader.load()

# You can now work with the loaded pages, for example, print the number of pages
print(f"Number of pages loaded: {len(pages)}")

# Or access the content of a specific page
if pages:
    print(pages[0].page_content[:200]) # Print the first 200 characters of the first page
# Out:
# Number of pages loaded: 7
# 4780/6780: Fundamentals of Data Science
# Kiril Kuzmin
# Spring, 2025
# E-mail: kkuzmin1@gsu.edu
# Office Hours: M 2:00–4:00pm Class Hours: M,W 5:30–7:15pm
# Office: 25 Park Place 750 Class Room: Langdale Hall

# %%
full_text = "\n\n".join([page.page_content for page in pages])
print(f"Loaded {len(pages)} pages, {len(full_text)} total characters")
# Out:
# Loaded 7 pages, 11227 total characters

# %%
# create chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=500,
    separators=["\n\n", "\n", ". ", " ", ""]
)
chunks = text_splitter.split_text(full_text)
print(f"Created {len(chunks)} chunks")
# Out:
# Created 12 chunks

# %%
# embedding
embeddings = GoogleGenerativeAIEmbeddings(
    model = "models/gemini-embedding-001"
)

# Create a Chroma vector store from the chunks
vectorstore = Chroma.from_texts(
    texts=chunks,
    embedding=embeddings,
    collection_name="TaskBudy_Phase1"
)

print(f"Stored {vectorstore._collection.count()} chunks in the vector store")
# Out:
# Stored 12 chunks in the vector store

# %%
retrieval = vectorstore.similarity_search("extract every assignment, project, or exam mentioned", k=5)
for i in retrieval:
  print(i,'\n')
# Out:
# page_content='✓ Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and
# modeling.
# ✓ Presentation (30 points): Deliver a clear and professional group presentation, followed by a
# Q&A.
# ✓ Final Report (25 points): Submit a detailed PDF report explaining your process, findings,
# and recommendations.
# Deadlines
# • February 18 th: Proposal submission (via email to kkuzmin1@gsu.edu with CC to all mem-
# bers).
# • April 16 th, April 21th, April 23th: Project presentations.
# • April 25 th: Final report submission.
# Further details and guidelines will be provided on iCollege.
# 4/7'
#
# page_content='4780/6780: Fundamentals of Data Science: Spring 2025
# • Encoding techniques and feature creation/extraction
# • Forward and backward feature selection
# Week 10: Model Evaluation and Hyperparameter T uning
# • Metrics: Accuracy, precision, recall (sensitivity), F1-score, specificity
# • ROC (Receiver Operating Characteristic) curve and thresholding
# • Cross-validation and grid search
# Week 11: Unsupervised Learning
# • Clustering techniques: k-means and hierarchical clustering
# • Dendrograms and their interpretation
# Week 12: Ensemble Models
# • Random forest
# • BAgging (Bootstrap Aggregating) and Boosting
# • AdaBoost (Adaptive Boosting) and Gradient boosting
# Week 13: Neural Networks and Project Presentations
# • Fundamentals of Neural networks
# • Project presentations
# Week 14: Final Review and Conclusion
# • Final exam preparation
# • Project presentations
# • Course wrap-up and next steps
# Homeworks
# Completing all assignments independently is essential for success in this class. You must strictly
# adhere to the homework submission requirements provided on iCollege.
# Each submission should consist of the source code as Jupyter notebook file (with an extension
# ipynb). The submissions must be uploaded on iCollege dropbox into the relevant folder.
# If the teaching assistant cannot open and read it, or if you submit a flawed document, the
# grade will be zero. It is your responsibility to ensure that each file opens correctly. Having'
#
# page_content='4780/6780: Fundamentals of Data Science: Spring 2025
# The grade will count the assessments using the following proportions:
# • 30% of your grade will be based on homework assignments (5 total, with the lowest score
# dropped).
# • 20% of your grade will be based on the project (proposal due February 18 th).
# • 25% of your grade will be based on the midterm, scheduled for regular class hours on
# Wednesday, February 26th (tentative).
# • 25% of your grade will be based on the final, held during exam week in the same classroom
# on Wednesday, April 30th, 4:15–6:00pm.
# Makeup exams – midterm and final – are not given! Exceptions to this policy may be made
# only in case of a family or medical emergency, which must be clearly documented AND submit-
# ted through Professor Absence Notification system. Please note that to be eligible for makeup
# exams, your absence request must be approved by the Office of the Dean of Students.
# Attendance
# Attendance at the lectures is not mandatory but is strongly encouraged. This class is one of
# the most crucial for aspiring data scientists and data analysts. We will focus on discussing and
# solving numerous problems frequently encountered in technical job interviews.
# Late Assignments
# Late assignments may be accepted for no penalty if a valid excuse is communicated to the in-
# structor before the deadline. If you exceed the deadline for more than 1 hour, your assignment
# will be penalized. The penalty is a 20% deduction for each extra 24 hours after the deadline.'
#
# page_content='pendently. If you get stuck, you may research approaches online (e.g., stackoverflow.com) or
# use generative AI tools (e.g., ChatGPT). However, avoid blindly copying solutions – understand
# them first, then close the resource and implement the solution based on your understanding and
# memory.
# Copying another student’s work will result in severe penalties, including a grade of zero for
# the activity (homework/exam) for all students involved. In some cases of plagiarism, at the
# instructor’s discretion, students may receive a failing grade for the course.
# 6/7'
#
# page_content='adhere to the homework submission requirements provided on iCollege.
# Each submission should consist of the source code as Jupyter notebook file (with an extension
# ipynb). The submissions must be uploaded on iCollege dropbox into the relevant folder.
# If the teaching assistant cannot open and read it, or if you submit a flawed document, the
# grade will be zero. It is your responsibility to ensure that each file opens correctly. Having
# submitted it on iCollege, go and try to open/download it. Make sure that you hit the “submit”
# button, and get a notification from iCollege that your submission has successfully gone through.
# Your homework assignments will be checked by
# Name Email Office hours
# Abhiram Gaddam agaddam2@student.gsu.edu in Webex by appointment
# 3/7'

# %%
# --- Prompt and Generation ---
template = """You are an academic assistant. Below is the text from several syllabus documents.
    Please extract every assignment, project, or exam mentioned.
    Format the output as a clean table with two columns: 'Assignment Name' and 'Due Date'.
    If a due date is missing, write 'Not Specified'

Context: {context}

Question: {question}

Answer:"""

prompt = ChatPromptTemplate.from_template(template)
llm = ChatGoogleGenerativeAI(model="gemini-flash-latest")

def format_docs(docs):
    return "\n\n---\n\n".join(doc.page_content for doc in docs)

rag_chain = (
    {"context": vectorstore.as_retriever(search_kwargs={"k": 5}) | format_docs,
    "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)
print("RAG chain built successfully.")
# Out:
# RAG chain built successfully.

# %%
from IPython.display import Markdown

response = rag_chain.invoke('Generate')
display(Markdown(response))
# Out:
# Based on the syllabus documents provided, here are the assignments, projects, and exams mentioned:
#
# | Assignment Name | Due Date |
# | :--- | :--- |
# | Homework Assignment 1 | Not Specified |
# | Homework Assignment 2 | Not Specified |
# | Homework Assignment 3 | Not Specified |
# | Homework Assignment 4 | Not Specified |
# | Homework Assignment 5 | Not Specified |
# | Project Proposal | February 18th |
# | Midterm Exam | February 26th (tentative) |
# | Project Presentation | April 16th, April 21st, or April 23rd |
# | Project Final Report | April 25th |
# | Project Implementation (Jupyter Notebooks) | Not Specified |
# | Final Exam | April 30th (4:15–6:00pm) |

# %% [markdown]
# will need to rewrite the function below and combine it with the retrieval above

# %%
# def extract_assignments():
#     raw_content = pages[0].page_content

#     prompt = f"""
#     You are an academic assistant. Below is the text from several syllabus documents.
#     Please extract every assignment, project, or exam mentioned.
#     Format the output as a clean table with two columns: 'Assignment Name' and 'Due Date'.
#     If a due date is missing, write 'Not Specified'.

#     SYLLABUS TEXT:
#     {raw_content}
#     """

#     response = llm.invoke(prompt)
#     return response.content

# # Run the agent
# assignments_list = extract_assignments()
# print(assignments_list)

# %% [markdown]
# ## Google Calendar

# %%
# %pip install -qU langchain-google-community\[calendar\]
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\requirements.py", line 36, in __init__
#     parsed = _parse_requirement(requirement_string)
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_parser.py", line 62, in parse_requirement
#     return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_parser.py", line 77, in _parse_requirement
#     extras = _parse_extras(tokenizer)
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_parser.py", line 164, in _parse_extras
#     with tokenizer.enclosing_tokens(
#          ~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         "LEFT_BRACKET",
#         ^^^^^^^^^^^^^^^
#         "RIGHT_BRACKET",
#         ^^^^^^^^^^^^^^^^
#         around="extras",
#         ^^^^^^^^^^^^^^^^
#     ):
#     ^
#   File "c:\python313\Lib\contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_tokenizer.py", line 190, in enclosing_tokens
#     self.raise_syntax_error(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         f"Expected matching {close_token} for {open_token}, after {around}",
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         span_start=open_position,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_tokenizer.py", line 168, in raise_syntax_error
#     raise ParserSyntaxError(
#     ...<3 lines>...
#     )
# pip._vendor.packaging._tokenizer.ParserSyntaxError: Expected matching RIGHT_BRACKET for LEFT_BRACKET, after extras
#     placeholder[calendar\]
#                ~~~~~~~~~^
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\base_command.py", line 107, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\base_command.py", line 98, in _inner_run
#     return self.run(options, args)
#            ~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\req_command.py", line 71, in wrapper
#     return func(self, options, args)
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_internal\commands\install.py", line 357, in run
#     reqs = self.get_requirements(args, options, finder, session)
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\req_command.py", line 240, in get_requirements
#     req_to_add = install_req_from_line(
#         req,
#     ...<4 lines>...
#         config_settings=getattr(options, "config_settings", None),
#     )
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_internal\req\constructors.py", line 407, in install_req_from_line
#     parts = parse_req_from_line(name, line_source)
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_internal\req\constructors.py", line 355, in parse_req_from_line
#     extras = convert_extras(extras_as_string)
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_internal\req\constructors.py", line 61, in convert_extras
#     return get_requirement("placeholder" + extras.lower()).extras
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_internal\utils\packaging.py", line 44, in get_requirement
#     return Requirement(req_string)
#   File "C:\Users\abdif\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\requirements.py", line 38, in __init__
#     raise InvalidRequirement(str(e)) from e
# pip._vendor.packaging.requirements.InvalidRequirement: Expected matching RIGHT_BRACKET for LEFT_BRACKET, after extras
#     placeholder[calendar\]
#                ~~~~~~~~~^

# %%
# %pip install google-auth-oauthlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-auth-oauthlib in c:\users\abdif\appdata\roaming\python\python313\site-packages (1.2.4)
# Requirement already satisfied: google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from google-auth-oauthlib) (2.48.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (44.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.6.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\abdif\appdata\roaming\python\python313\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (2.22)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import datetime
import zoneinfo
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

SCOPES = ["https://www.googleapis.com/auth/calendar.events"]


def event_exists(service, title, start_time, end_time):
    """Check if an event with same title exists in the time window"""
    events_result = service.events().list(
        calendarId="primary",
        timeMin=start_time,
        timeMax=end_time,
        singleEvents=True,
        orderBy="startTime"
    ).execute()




    events = events_result.get("items", [])

    for e in events:
        if e.get("summary") == title:
            return True

    return False



def main():
    creds = None

    if os.path.exists("token.json"):
        creds = Credentials.from_authorized_user_file("token.json", SCOPES)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                "credentials.json", SCOPES
            )
            creds = flow.run_local_server(port=0)

        with open("token.json", "w") as token:
            token.write(creds.to_json())





    try:
        service = build("calendar", "v3", credentials=creds)

        title = "Final Exam"

        tz = zoneinfo.ZoneInfo("America/Chicago")

        start_dt = datetime.datetime(2026, 4, 30, 16, 15, 0, tzinfo=tz)
        end_dt = datetime.datetime(2026, 4, 30, 18, 0, 0, tzinfo=tz)

        start_iso = start_dt.isoformat()
        end_iso = end_dt.isoformat()
        
        if event_exists(service, title, start_iso, end_iso):
            print("event already exists!")
            return
        
        # 🔥 Event details
        event = {
            "summary": title,
            "location": "Not mentioned",
            "description": "Preparing for cloud + cybersecurity internship",
            "start": {
                "dateTime": start_iso,
                "timeZone": "America/Chicago",
            },
            "end": {
                "dateTime": end_iso,
                "timeZone": "America/Chicago",
            },
            "reminders": {
                "useDefault": False,
                "overrides": [
                    {"method": "popup", "minutes": 30},
                    {"method": "popup", "minutes": 10},
                ],
            }
        }

        created_event = service.events().insert(
            calendarId="primary",
            body=event
        ).execute()

        print("Event created:", created_event.get("htmlLink"))

    except HttpError as error:
        print(f"An error occurred: {error}")

if __name__ == "__main__":
    main()
# Out:
# Event created: https://www.google.com/calendar/event?eid=MmVpZTI3bHQxOXNlM2Z1NHAxYTVmdXNyc2sgYWJkaWZhdGFoaWlkQG0

# %% [markdown]
# ## Docling - doc parser

# %%
# %pip install docling torch torchvision
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting docling
#   Downloading docling-2.75.0-py3-none-any.whl.metadata (12 kB)
# Collecting torch
#   Downloading torch-2.10.0-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading torchvision-0.25.0-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling) (2.12.5)
# Collecting docling-core<3.0.0,>=2.62.0 (from docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading docling_core-2.66.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting docling-parse<6.0.0,>=5.3.2 (from docling)
#   Downloading docling_parse-5.4.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting docling-ibm-models<4,>=3.9.1 (from docling)
#   Downloading docling_ibm_models-3.11.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling) (1.2.0)
# Collecting pypdfium2!=4.30.1,<6.0.0,>=4.30.0 (from docling)
#   Downloading pypdfium2-5.5.0-py3-none-win_amd64.whl.metadata (68 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling) (2.13.1)
# Collecting huggingface_hub<1,>=0.23 (from docling)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling) (2.32.5)
# Collecting rapidocr<4.0.0,>=3.3 (from docling)
#   Downloading rapidocr-3.6.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling) (2025.8.3)
# Collecting rtree<2.0.0,>=1.3.0 (from docling)
#   Downloading rtree-1.4.1-py3-none-win_amd64.whl.metadata (2.2 kB)
# Collecting typer<0.22.0,>=0.12.5 (from docling)
#   Downloading typer-0.21.2-py3-none-any.whl.metadata (16 kB)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from docling)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling) (2.3.0)
# Collecting marko<3.0.0,>=2.1.2 (from docling)
#   Downloading marko-2.2.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting openpyxl<4.0.0,>=3.1.5 (from docling)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting lxml<7.0.0,>=4.0.0 (from docling)
#   Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow<13.0.0,>=10.0.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling) (11.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling) (4.67.3)
# Collecting pluggy<2.0.0,>=1.0.0 (from docling)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting pylatexenc<3.0,>=2.10 (from docling)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling) (1.16.0)
# Collecting accelerate<2,>=1.0.0 (from docling)
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting polyfactory>=2.22.2 (from docling)
#   Downloading polyfactory-3.3.0-py3-none-any.whl.metadata (27 kB)
# Collecting defusedxml<0.8.0,>=0.7.1 (from docling)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from accelerate<2,>=1.0.0->docling) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from accelerate<2,>=1.0.0->docling) (25.0)
# Requirement already satisfied: psutil in c:\users\abdif\appdata\roaming\python\python313\site-packages (from accelerate<2,>=1.0.0->docling) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\abdif\appdata\roaming\python\python313\site-packages (from accelerate<2,>=1.0.0->docling) (6.0.2)
# Collecting safetensors>=0.4.3 (from accelerate<2,>=1.0.0->docling)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4<5.0.0,>=4.12.3->docling)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (4.15.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (4.26.0)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting tabulate<0.10.0,>=0.9.0 (from docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading latex2mathml-3.78.1-py3-none-any.whl.metadata (15 kB)
# Collecting semchunk<3.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading semchunk-2.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting tree-sitter<0.27.0,>=0.25.0 (from docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading tree_sitter-0.25.2-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Collecting tree-sitter-python>=0.23.6 (from docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading tree_sitter_python-0.25.0-cp310-abi3-win_amd64.whl.metadata (1.9 kB)
# Collecting tree-sitter-c>=0.23.4 (from docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading tree_sitter_c-0.24.1-cp310-abi3-win_amd64.whl.metadata (1.8 kB)
# Collecting tree-sitter-javascript>=0.23.1 (from docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading tree_sitter_javascript-0.25.0-cp310-abi3-win_amd64.whl.metadata (2.3 kB)
# Collecting tree-sitter-typescript>=0.23.2 (from docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading tree_sitter_typescript-0.23.2-cp39-abi3-win_amd64.whl.metadata (2.4 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Collecting jsonlines<5.0.0,>=3.1.0 (from docling-ibm-models<4,>=3.9.1->docling)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: filelock in c:\users\abdif\appdata\roaming\python\python313\site-packages (from torch) (3.24.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from torch) (1.14.0)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: setuptools in c:\users\abdif\appdata\roaming\python\python313\site-packages (from torch) (80.9.0)
# Requirement already satisfied: pywin32>=305 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from docling-parse<6.0.0,>=5.3.2->docling) (310)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jsonlines<5.0.0,>=3.1.0->docling-ibm-models<4,>=3.9.1->docling) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.30.0)
# Collecting et-xmlfile (from openpyxl<4.0.0,>=3.1.5->docling)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from pydantic-settings<3.0.0,>=2.3.0->docling) (1.2.1)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyclipper>=1.2.0 (from rapidocr<4.0.0,>=3.3->docling)
#   Downloading pyclipper-1.4.0-cp313-cp313-win_amd64.whl.metadata (8.8 kB)
# Collecting opencv_python>=4.5.1.48 (from rapidocr<4.0.0,>=3.3->docling)
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: six>=1.15.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from rapidocr<4.0.0,>=3.3->docling) (1.17.0)
# Collecting Shapely!=2.0.4,>=1.7.1 (from rapidocr<4.0.0,>=3.3->docling)
#   Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Collecting omegaconf (from rapidocr<4.0.0,>=3.3->docling)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting colorlog (from rapidocr<4.0.0,>=3.3->docling)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.2->docling) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.2->docling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.2->docling) (2.5.0)
# Collecting mpire[dill] (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: colorama in c:\users\abdif\appdata\roaming\python\python313\site-packages (from tqdm<5.0.0,>=4.65.0->docling) (0.4.6)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading regex-2026.2.28-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.22.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from typer<0.22.0,>=0.12.5->docling) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from typer<0.22.0,>=0.12.5->docling) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from typer<0.22.0,>=0.12.5->docling) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from typer<0.22.0,>=0.12.5->docling) (14.0.0)
# Collecting faker>=5.0.0 (from polyfactory>=2.22.2->docling)
#   Downloading faker-40.5.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer<0.22.0,>=0.12.5->docling) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer<0.22.0,>=0.12.5->docling) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.22.0,>=0.12.5->docling) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abdif\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# Collecting multiprocess>=0.70.15 (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading multiprocess-0.70.19-py313-none-any.whl.metadata (7.5 kB)
# Collecting dill>=0.4.1 (from multiprocess>=0.70.15->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.62.0->docling)
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->rapidocr<4.0.0,>=3.3->docling)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Downloading docling-2.75.0-py3-none-any.whl (396 kB)
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading docling_core-2.66.0-py3-none-any.whl (241 kB)
# Downloading docling_ibm_models-3.11.0-py3-none-any.whl (87 kB)
# Downloading torch-2.10.0-cp313-cp313-win_amd64.whl (113.8 MB)
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    ---------------------------------------- 0.8/113.8 MB 4.5 MB/s eta 0:00:25
#     --------------------------------------- 1.8/113.8 MB 4.3 MB/s eta 0:00:26
#     --------------------------------------- 2.6/113.8 MB 4.0 MB/s eta 0:00:29
#    - -------------------------------------- 3.1/113.8 MB 3.8 MB/s eta 0:00:29
#    - -------------------------------------- 4.2/113.8 MB 3.9 MB/s eta 0:00:29
#    - -------------------------------------- 5.0/113.8 MB 3.9 MB/s eta 0:00:28
#    -- ------------------------------------- 5.8/113.8 MB 3.9 MB/s eta 0:00:28
#    -- ------------------------------------- 6.8/113.8 MB 4.0 MB/s eta 0:00:27
#    -- ------------------------------------- 7.6/113.8 MB 4.0 MB/s eta 0:00:27
#    --- ------------------------------------ 8.7/113.8 MB 4.1 MB/s eta 0:00:26
#    --- ------------------------------------ 9.4/113.8 MB 4.1 MB/s eta 0:00:26
#    --- ------------------------------------ 10.5/113.8 MB 4.2 MB/s eta 0:00:25
#    ---- ----------------------------------- 11.5/113.8 MB 4.2 MB/s eta 0:00:25
#    ---- ----------------------------------- 12.3/113.8 MB 4.1 MB/s eta 0:00:25
#    ---- ----------------------------------- 13.4/113.8 MB 4.2 MB/s eta 0:00:25
#    ---- ----------------------------------- 14.2/113.8 MB 4.2 MB/s eta 0:00:24
#    ----- ---------------------------------- 15.2/113.8 MB 4.2 MB/s eta 0:00:24
#    ----- ---------------------------------- 16.0/113.8 MB 4.2 MB/s eta 0:00:24
#    ----- ---------------------------------- 16.8/113.8 MB 4.1 MB/s eta 0:00:24
#    ------ --------------------------------- 17.3/113.8 MB 4.1 MB/s eta 0:00:24
#    ------ --------------------------------- 17.8/113.8 MB 4.1 MB/s eta 0:00:24
#    ------ --------------------------------- 18.6/113.8 MB 4.0 MB/s eta 0:00:25
#    ------ --------------------------------- 19.1/113.8 MB 3.9 MB/s eta 0:00:25
#    ------- -------------------------------- 19.9/113.8 MB 3.9 MB/s eta 0:00:25
#    ------- -------------------------------- 20.7/113.8 MB 3.9 MB/s eta 0:00:25
#    ------- -------------------------------- 21.5/113.8 MB 3.9 MB/s eta 0:00:24
#    ------- -------------------------------- 22.0/113.8 MB 3.8 MB/s eta 0:00:24
#    ------- -------------------------------- 22.5/113.8 MB 3.8 MB/s eta 0:00:25
#    -------- ------------------------------- 23.1/113.8 MB 3.8 MB/s eta 0:00:25
#    -------- ------------------------------- 23.9/113.8 MB 3.7 MB/s eta 0:00:25
#    -------- ------------------------------- 24.4/113.8 MB 3.7 MB/s eta 0:00:24
#    -------- ------------------------------- 25.2/113.8 MB 3.7 MB/s eta 0:00:24
#    --------- ------------------------------ 26.0/113.8 MB 3.7 MB/s eta 0:00:24
#    --------- ------------------------------ 26.5/113.8 MB 3.7 MB/s eta 0:00:24
#    --------- ------------------------------ 27.3/113.8 MB 3.7 MB/s eta 0:00:24
#    --------- ------------------------------ 27.8/113.8 MB 3.7 MB/s eta 0:00:24
#    ---------- ----------------------------- 28.6/113.8 MB 3.6 MB/s eta 0:00:24
#    ---------- ----------------------------- 29.1/113.8 MB 3.6 MB/s eta 0:00:24
#    ---------- ----------------------------- 30.1/113.8 MB 3.6 MB/s eta 0:00:24
#    ---------- ----------------------------- 30.9/113.8 MB 3.6 MB/s eta 0:00:23
#    ----------- ---------------------------- 31.7/113.8 MB 3.6 MB/s eta 0:00:23
#    ----------- ---------------------------- 32.8/113.8 MB 3.6 MB/s eta 0:00:23
#    ----------- ---------------------------- 33.6/113.8 MB 3.7 MB/s eta 0:00:22
#    ------------ --------------------------- 34.3/113.8 MB 3.6 MB/s eta 0:00:22
#    ------------ --------------------------- 35.1/113.8 MB 3.6 MB/s eta 0:00:22
#    ------------ --------------------------- 35.7/113.8 MB 3.6 MB/s eta 0:00:22
#    ------------ --------------------------- 36.7/113.8 MB 3.7 MB/s eta 0:00:22
#    ------------- -------------------------- 37.5/113.8 MB 3.7 MB/s eta 0:00:21
#    ------------- -------------------------- 38.5/113.8 MB 3.7 MB/s eta 0:00:21
#    ------------- -------------------------- 39.3/113.8 MB 3.7 MB/s eta 0:00:21
#    -------------- ------------------------- 40.1/113.8 MB 3.7 MB/s eta 0:00:20
#    -------------- ------------------------- 40.9/113.8 MB 3.7 MB/s eta 0:00:20
#    -------------- ------------------------- 41.7/113.8 MB 3.7 MB/s eta 0:00:20
#    --------------- ------------------------ 42.7/113.8 MB 3.7 MB/s eta 0:00:20
#    --------------- ------------------------ 43.5/113.8 MB 3.7 MB/s eta 0:00:19
#    --------------- ------------------------ 44.3/113.8 MB 3.7 MB/s eta 0:00:19
#    --------------- ------------------------ 45.1/113.8 MB 3.7 MB/s eta 0:00:19
#    ---------------- ----------------------- 45.9/113.8 MB 3.7 MB/s eta 0:00:19
#    ---------------- ----------------------- 46.9/113.8 MB 3.7 MB/s eta 0:00:18
#    ---------------- ----------------------- 47.4/113.8 MB 3.7 MB/s eta 0:00:18
#    ---------------- ----------------------- 48.2/113.8 MB 3.7 MB/s eta 0:00:18
#    ----------------- ---------------------- 49.0/113.8 MB 3.7 MB/s eta 0:00:18
#    ----------------- ---------------------- 50.1/113.8 MB 3.7 MB/s eta 0:00:18
#    ----------------- ---------------------- 50.9/113.8 MB 3.7 MB/s eta 0:00:17
#    ------------------ --------------------- 51.9/113.8 MB 3.7 MB/s eta 0:00:17
#    ------------------ --------------------- 52.7/113.8 MB 3.7 MB/s eta 0:00:17
#    ------------------ --------------------- 53.5/113.8 MB 3.7 MB/s eta 0:00:17
#    ------------------- -------------------- 54.3/113.8 MB 3.7 MB/s eta 0:00:17
#    ------------------- -------------------- 54.8/113.8 MB 3.7 MB/s eta 0:00:16
#    ------------------- -------------------- 55.6/113.8 MB 3.7 MB/s eta 0:00:16
#    ------------------- -------------------- 56.4/113.8 MB 3.7 MB/s eta 0:00:16
#    -------------------- ------------------- 57.1/113.8 MB 3.7 MB/s eta 0:00:16
#    -------------------- ------------------- 57.7/113.8 MB 3.7 MB/s eta 0:00:16
#    -------------------- ------------------- 58.2/113.8 MB 3.7 MB/s eta 0:00:16
#    -------------------- ------------------- 58.7/113.8 MB 3.7 MB/s eta 0:00:16
#    -------------------- ------------------- 59.2/113.8 MB 3.6 MB/s eta 0:00:16
#    --------------------- ------------------ 59.8/113.8 MB 3.6 MB/s eta 0:00:15
#    --------------------- ------------------ 60.3/113.8 MB 3.6 MB/s eta 0:00:15
#    --------------------- ------------------ 61.1/113.8 MB 3.6 MB/s eta 0:00:15
#    --------------------- ------------------ 61.9/113.8 MB 3.6 MB/s eta 0:00:15
#    ---------------------- ----------------- 62.7/113.8 MB 3.6 MB/s eta 0:00:15
#    ---------------------- ----------------- 63.2/113.8 MB 3.6 MB/s eta 0:00:15
#    ---------------------- ----------------- 64.0/113.8 MB 3.6 MB/s eta 0:00:14
#    ---------------------- ----------------- 64.7/113.8 MB 3.6 MB/s eta 0:00:14
#    ----------------------- ---------------- 65.5/113.8 MB 3.6 MB/s eta 0:00:14
#    ----------------------- ---------------- 66.3/113.8 MB 3.6 MB/s eta 0:00:14
#    ----------------------- ---------------- 67.6/113.8 MB 3.6 MB/s eta 0:00:13
#    ------------------------ --------------- 68.4/113.8 MB 3.6 MB/s eta 0:00:13
#    ------------------------ --------------- 69.5/113.8 MB 3.6 MB/s eta 0:00:13
#    ------------------------ --------------- 70.5/113.8 MB 3.6 MB/s eta 0:00:12
#    ------------------------- -------------- 71.3/113.8 MB 3.6 MB/s eta 0:00:12
#    ------------------------- -------------- 72.1/113.8 MB 3.7 MB/s eta 0:00:12
#    ------------------------- -------------- 72.9/113.8 MB 3.7 MB/s eta 0:00:12
#    ------------------------- -------------- 73.9/113.8 MB 3.7 MB/s eta 0:00:11
#    -------------------------- ------------- 74.7/113.8 MB 3.7 MB/s eta 0:00:11
#    -------------------------- ------------- 75.5/113.8 MB 3.7 MB/s eta 0:00:11
#    -------------------------- ------------- 76.5/113.8 MB 3.7 MB/s eta 0:00:11
#    --------------------------- ------------ 77.6/113.8 MB 3.7 MB/s eta 0:00:10
#    --------------------------- ------------ 78.4/113.8 MB 3.7 MB/s eta 0:00:10
#    --------------------------- ------------ 79.4/113.8 MB 3.7 MB/s eta 0:00:10
#    ---------------------------- ----------- 80.5/113.8 MB 3.7 MB/s eta 0:00:09
#    ---------------------------- ----------- 81.3/113.8 MB 3.7 MB/s eta 0:00:09
#    ---------------------------- ----------- 82.1/113.8 MB 3.7 MB/s eta 0:00:09
#    ----------------------------- ---------- 83.1/113.8 MB 3.7 MB/s eta 0:00:09
#    ----------------------------- ---------- 83.9/113.8 MB 3.7 MB/s eta 0:00:09
#    ----------------------------- ---------- 84.7/113.8 MB 3.7 MB/s eta 0:00:08
#    ------------------------------ --------- 85.5/113.8 MB 3.7 MB/s eta 0:00:08
#    ------------------------------ --------- 86.5/113.8 MB 3.7 MB/s eta 0:00:08
#    ------------------------------ --------- 87.3/113.8 MB 3.7 MB/s eta 0:00:08
#    ------------------------------- -------- 88.3/113.8 MB 3.8 MB/s eta 0:00:07
#    ------------------------------- -------- 89.1/113.8 MB 3.8 MB/s eta 0:00:07
#    ------------------------------- -------- 90.2/113.8 MB 3.8 MB/s eta 0:00:07
#    ------------------------------- -------- 91.0/113.8 MB 3.8 MB/s eta 0:00:07
#    -------------------------------- ------- 92.0/113.8 MB 3.8 MB/s eta 0:00:06
#    -------------------------------- ------- 92.8/113.8 MB 3.8 MB/s eta 0:00:06
#    -------------------------------- ------- 93.8/113.8 MB 3.8 MB/s eta 0:00:06
#    --------------------------------- ------ 94.9/113.8 MB 3.8 MB/s eta 0:00:05
#    --------------------------------- ------ 95.7/113.8 MB 3.8 MB/s eta 0:00:05
#    ---------------------------------- ----- 96.7/113.8 MB 3.8 MB/s eta 0:00:05
#    ---------------------------------- ----- 97.5/113.8 MB 3.8 MB/s eta 0:00:05
#    ---------------------------------- ----- 98.6/113.8 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 99.6/113.8 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 100.4/113.8 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 100.7/113.8 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 101.4/113.8 MB 3.8 MB/s eta 0:00:04
#    ----------------------------------- ---- 102.0/113.8 MB 3.8 MB/s eta 0:00:04
#    ------------------------------------ --- 103.0/113.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 103.8/113.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 104.6/113.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------- -- 105.4/113.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------- -- 106.4/113.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 107.2/113.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 108.3/113.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 109.1/113.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 109.8/113.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 110.4/113.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 110.9/113.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  111.9/113.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  112.5/113.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  113.2/113.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 113.8/113.8 MB 3.7 MB/s  0:00:30
# Downloading torchvision-0.25.0-cp313-cp313-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.3 MB 4.2 MB/s eta 0:00:01
#    ------------ --------------------------- 1.3/4.3 MB 3.8 MB/s eta 0:00:01
#    --------------------- ------------------ 2.4/4.3 MB 3.8 MB/s eta 0:00:01
#    -------------------------- ------------- 2.9/4.3 MB 3.7 MB/s eta 0:00:01
#    ------------------------------- -------- 3.4/4.3 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 3.2 MB/s  0:00:01
# Downloading docling_parse-5.4.0-cp313-cp313-win_amd64.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.2 MB 4.1 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/9.2 MB 3.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.2 MB 3.9 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.2 MB 3.7 MB/s eta 0:00:02
#    ------------------ --------------------- 4.2/9.2 MB 3.7 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.2 MB 3.5 MB/s eta 0:00:02
#    ------------------------ --------------- 5.5/9.2 MB 3.5 MB/s eta 0:00:02
#    -------------------------- ------------- 6.0/9.2 MB 3.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.2 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 7.3/9.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.9/9.2 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 8.4/9.2 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.2 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 3.2 MB/s  0:00:02
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ---------------------------------------- 0.0/566.4 kB ? eta -:--:--
#    ---------------------------------------- 566.4/566.4 kB 3.7 MB/s  0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading latex2mathml-3.78.1-py3-none-any.whl (73 kB)
# Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 4.0 MB/s eta 0:00:01
#    --------------- ------------------------ 1.6/4.0 MB 3.9 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.0 MB 3.6 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 3.1 MB/s  0:00:01
# Downloading marko-2.2.2-py3-none-any.whl (42 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading pypdfium2-5.5.0-py3-none-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.8/3.1 MB 5.1 MB/s eta 0:00:01
#    -------------------- ------------------- 1.6/3.1 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 2.4/3.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 1.8 MB/s  0:00:01
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading rapidocr-3.6.0-py3-none-any.whl (15.1 MB)
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/15.1 MB 4.1 MB/s eta 0:00:04
#    --- ------------------------------------ 1.3/15.1 MB 3.9 MB/s eta 0:00:04
#    ------ --------------------------------- 2.4/15.1 MB 4.0 MB/s eta 0:00:04
#    -------- ------------------------------- 3.1/15.1 MB 4.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.9/15.1 MB 4.0 MB/s eta 0:00:03
#    ------------- -------------------------- 5.0/15.1 MB 4.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.0/15.1 MB 4.1 MB/s eta 0:00:03
#    ------------------ --------------------- 6.8/15.1 MB 4.1 MB/s eta 0:00:03
#    -------------------- ------------------- 7.6/15.1 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.7/15.1 MB 4.1 MB/s eta 0:00:02
#    ------------------------- -------------- 9.7/15.1 MB 4.2 MB/s eta 0:00:02
#    --------------------------- ------------ 10.5/15.1 MB 4.2 MB/s eta 0:00:02
#    ------------------------------ --------- 11.5/15.1 MB 4.3 MB/s eta 0:00:01
#    -------------------------------- ------- 12.3/15.1 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.4/15.1 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 14.2/15.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.1 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.1/15.1 MB 4.2 MB/s  0:00:03
# Downloading rtree-1.4.1-py3-none-win_amd64.whl (389 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Downloading semchunk-2.2.2-py3-none-any.whl (10 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.0 MB 3.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/12.0 MB 3.8 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/12.0 MB 3.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/12.0 MB 4.0 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.0 MB 4.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.0 MB 4.1 MB/s eta 0:00:02
#    -------------------- ------------------- 6.0/12.0 MB 4.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.1/12.0 MB 4.1 MB/s eta 0:00:02
#    -------------------------- ------------- 7.9/12.0 MB 4.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.9/12.0 MB 4.2 MB/s eta 0:00:01
#    -------------------------------- ------- 9.7/12.0 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.7/12.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 4.2 MB/s  0:00:02
# Downloading tree_sitter-0.25.2-cp313-cp313-win_amd64.whl (127 kB)
# Downloading typer-0.21.2-py3-none-any.whl (56 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.1 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.2 MB/s  0:00:00
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#     --------------------------------------- 0.8/40.2 MB 4.5 MB/s eta 0:00:09
#    - -------------------------------------- 1.8/40.2 MB 4.3 MB/s eta 0:00:09
#    -- ------------------------------------- 2.6/40.2 MB 4.2 MB/s eta 0:00:10
#    --- ------------------------------------ 3.4/40.2 MB 4.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.5/40.2 MB 4.3 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.5/40.2 MB 4.4 MB/s eta 0:00:08
#    ------ --------------------------------- 6.6/40.2 MB 4.5 MB/s eta 0:00:08
#    ------- -------------------------------- 7.6/40.2 MB 4.5 MB/s eta 0:00:08
#    -------- ------------------------------- 8.4/40.2 MB 4.5 MB/s eta 0:00:08
#    --------- ------------------------------ 9.4/40.2 MB 4.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.5/40.2 MB 4.5 MB/s eta 0:00:07
#    ----------- ---------------------------- 11.5/40.2 MB 4.5 MB/s eta 0:00:07
#    ------------ --------------------------- 12.6/40.2 MB 4.6 MB/s eta 0:00:07
#    ------------- -------------------------- 13.4/40.2 MB 4.5 MB/s eta 0:00:06
#    -------------- ------------------------- 14.7/40.2 MB 4.6 MB/s eta 0:00:06
#    --------------- ------------------------ 15.5/40.2 MB 4.6 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.5/40.2 MB 4.6 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.6/40.2 MB 4.6 MB/s eta 0:00:05
#    ------------------ --------------------- 18.6/40.2 MB 4.6 MB/s eta 0:00:05
#    ------------------- -------------------- 19.7/40.2 MB 4.6 MB/s eta 0:00:05
#    -------------------- ------------------- 20.4/40.2 MB 4.6 MB/s eta 0:00:05
#    --------------------- ------------------ 21.5/40.2 MB 4.6 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.5/40.2 MB 4.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 23.3/40.2 MB 4.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 24.1/40.2 MB 4.5 MB/s eta 0:00:04
#    ------------------------ --------------- 24.6/40.2 MB 4.5 MB/s eta 0:00:04
#    ------------------------- -------------- 25.4/40.2 MB 4.4 MB/s eta 0:00:04
#    -------------------------- ------------- 26.2/40.2 MB 4.4 MB/s eta 0:00:04
#    -------------------------- ------------- 27.0/40.2 MB 4.4 MB/s eta 0:00:04
#    --------------------------- ------------ 27.8/40.2 MB 4.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 28.6/40.2 MB 4.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 29.4/40.2 MB 4.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 30.1/40.2 MB 4.3 MB/s eta 0:00:03
#    ------------------------------- -------- 31.2/40.2 MB 4.3 MB/s eta 0:00:03
#    ------------------------------- -------- 32.0/40.2 MB 4.3 MB/s eta 0:00:02
#    -------------------------------- ------- 33.0/40.2 MB 4.3 MB/s eta 0:00:02
#    --------------------------------- ------ 34.1/40.2 MB 4.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.1/40.2 MB 4.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 36.2/40.2 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 37.2/40.2 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 38.3/40.2 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 39.1/40.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 4.3 MB/s  0:00:09
# Downloading polyfactory-3.3.0-py3-none-any.whl (62 kB)
# Downloading faker-40.5.1-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/2.0 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.8 MB/s  0:00:00
# Downloading pyclipper-1.4.0-cp313-cp313-win_amd64.whl (104 kB)
# Downloading regex-2026.2.28-cp313-cp313-win_amd64.whl (277 kB)
# Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.3 MB/s  0:00:00
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Downloading tree_sitter_c-0.24.1-cp310-abi3-win_amd64.whl (84 kB)
# Downloading tree_sitter_javascript-0.25.0-cp310-abi3-win_amd64.whl (62 kB)
# Downloading tree_sitter_python-0.25.0-cp310-abi3-win_amd64.whl (76 kB)
# Downloading tree_sitter_typescript-0.23.2-cp39-abi3-win_amd64.whl (278 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
# Downloading multiprocess-0.70.19-py313-none-any.whl (156 kB)
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Building wheels for collected packages: pylatexenc, antlr4-python3-runtime
#   Building wheel for pylatexenc (setup.py): started
#   Building wheel for pylatexenc (setup.py): finished with status 'done'
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136928 sha256=6a6891cbc263058d496180b39853f53be012183d149e02dbc9444808677135e9
#   Stored in directory: c:\users\abdif\appdata\local\pip\cache\wheels\3c\d9\c1\bb2a15d13c742b9035ef7ae6ebe236af270b1d1d9b386dcd5e
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144615 sha256=e95d5dc083c9e0bb27319b2e43a601ccb610411f975ea739119598f27c32f40f
#   Stored in directory: c:\users\abdif\appdata\local\pip\cache\wheels\d5\b3\74\a35b66048c9de6631cd74cbc9475e6feb3e69a467983446bd8
# Successfully built pylatexenc antlr4-python3-runtime
# Installing collected packages: pylatexenc, antlr4-python3-runtime, XlsxWriter, tree-sitter-typescript, tree-sitter-python, tree-sitter-javascript, tree-sitter-c, tree-sitter, tabulate, soupsieve, Shapely, safetensors, rtree, regex, pypdfium2, pyclipper, pluggy, opencv_python, omegaconf, networkx, marko, lxml, latex2mathml, jsonref, jsonlines, faker, et-xmlfile, dill, defusedxml, colorlog, torch, rapidocr, python-pptx, python-docx, polyfactory, openpyxl, multiprocess, mpire, huggingface_hub, beautifulsoup4, typer, torchvision, accelerate, transformers, semchunk, docling-core, docling-parse, docling-ibm-models, docling
#
#    ----------------------------------------  0/49 [pylatexenc]
#    ----------------------------------------  0/49 [pylatexenc]
#    ----------------------------------------  0/49 [pylatexenc]
#    ----------------------------------------  0/49 [pylatexenc]
#     ---------------------------------------  1/49 [antlr4-python3-runtime]
#     ---------------------------------------  1/49 [antlr4-python3-runtime]
#     ---------------------------------------  1/49 [antlr4-python3-runtime]
#     ---------------------------------------  1/49 [antlr4-python3-runtime]
#    - --------------------------------------  2/49 [XlsxWriter]
#    - --------------------------------------  2/49 [XlsxWriter]
#    - --------------------------------------  2/49 [XlsxWriter]
#    - --------------------------------------  2/49 [XlsxWriter]
#    - --------------------------------------  2/49 [XlsxWriter]
#    - --------------------------------------  2/49 [XlsxWriter]
#    - --------------------------------------  2/49 [XlsxWriter]
#    ---- -----------------------------------  5/49 [tree-sitter-javascript]
#    ------ ---------------------------------  8/49 [tabulate]
#    ------- --------------------------------  9/49 [soupsieve]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 10/49 [Shapely]
#    -------- ------------------------------- 11/49 [safetensors]
#    --------- ------------------------------ 12/49 [rtree]
#    --------- ------------------------------ 12/49 [rtree]
#    ---------- ----------------------------- 13/49 [regex]
#    ----------- ---------------------------- 14/49 [pypdfium2]
#    ----------- ---------------------------- 14/49 [pypdfium2]
#    ----------- ---------------------------- 14/49 [pypdfium2]
#    ----------- ---------------------------- 14/49 [pypdfium2]
#    ----------- ---------------------------- 14/49 [pypdfium2]
#    ----------- ---------------------------- 14/49 [pypdfium2]
#    ------------- -------------------------- 16/49 [pluggy]
#    ------------- -------------------------- 17/49 [opencv_python]
#    ------------- -------------------------- 17/49 [opencv_python]
#    ------------- -------------------------- 17/49 [opencv_python]
#    ------------- -------------------------- 17/49 [opencv_python]
#    ------------- -------------------------- 17/49 [opencv_python]
#    ------------- -------------------------- 17/49 [opencv_python]
#    ------------- -------------------------- 17/49 [opencv_python]
#    ------------- -------------------------- 17/49 [opencv_python]
#    -------------- ------------------------- 18/49 [omegaconf]
#    -------------- ------------------------- 18/49 [omegaconf]
#    -------------- ------------------------- 18/49 [omegaconf]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
#    --------------- ------------------------ 19/49 [networkx]
# ...
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ----------------------------------- ---- 43/49 [transformers]
#    ------------------------------------ --- 45/49 [docling-core]
#    ------------------------------------ --- 45/49 [docling-core]
#    ------------------------------------ --- 45/49 [docling-core]
#    ------------------------------------ --- 45/49 [docling-core]
#    ------------------------------------ --- 45/49 [docling-core]
#    ------------------------------------ --- 45/49 [docling-core]
#    ------------------------------------ --- 45/49 [docling-core]
#    ------------------------------------ --- 45/49 [docling-core]
#    ------------------------------------ --- 45/49 [docling-core]
#    ------------------------------------- -- 46/49 [docling-parse]
#    ------------------------------------- -- 46/49 [docling-parse]
#    ------------------------------------- -- 46/49 [docling-parse]
#    ------------------------------------- -- 46/49 [docling-parse]
#    ------------------------------------- -- 46/49 [docling-parse]
#    ------------------------------------- -- 46/49 [docling-parse]
#    -------------------------------------- - 47/49 [docling-ibm-models]
#    -------------------------------------- - 47/49 [docling-ibm-models]
#    -------------------------------------- - 47/49 [docling-ibm-models]
#    -------------------------------------- - 47/49 [docling-ibm-models]
#    -------------------------------------- - 47/49 [docling-ibm-models]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------  48/49 [docling]
#    ---------------------------------------- 49/49 [docling]
#
# Successfully installed Shapely-2.1.2 XlsxWriter-3.2.9 accelerate-1.12.0 antlr4-python3-runtime-4.9.3 beautifulsoup4-4.14.3 colorlog-6.10.1 defusedxml-0.7.1 dill-0.4.1 docling-2.75.0 docling-core-2.66.0 docling-ibm-models-3.11.0 docling-parse-5.4.0 et-xmlfile-2.0.0 faker-40.5.1 huggingface_hub-0.36.2 jsonlines-4.0.0 jsonref-1.1.0 latex2mathml-3.78.1 lxml-6.0.2 marko-2.2.2 mpire-2.10.2 multiprocess-0.70.19 networkx-3.6.1 omegaconf-2.3.0 opencv_python-4.13.0.92 openpyxl-3.1.5 pluggy-1.6.0 polyfactory-3.3.0 pyclipper-1.4.0 pylatexenc-2.10 pypdfium2-5.5.0 python-docx-1.2.0 python-pptx-1.0.2 rapidocr-3.6.0 regex-2026.2.28 rtree-1.4.1 safetensors-0.7.0 semchunk-2.2.2 soupsieve-2.8.3 tabulate-0.9.0 torch-2.10.0 torchvision-0.25.0 transformers-4.57.6 tree-sitter-0.25.2 tree-sitter-c-0.24.1 tree-sitter-javascript-0.25.0 tree-sitter-python-0.25.0 tree-sitter-typescript-0.23.2 typer-0.21.2
#   DEPRECATION: Building 'pylatexenc' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pylatexenc'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   DEPRECATION: Building 'antlr4-python3-runtime' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'antlr4-python3-runtime'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# typer-slim 0.24.0 requires typer>=0.24.0, but you have typer 0.21.2 which is incompatible.
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install -qU langchain-docling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_docling.loader import DoclingLoader

file = r"C:\Users\abdif\OneDrive\Documents\TaskBuddy\Syllabi\Syllabus.pdf"

loader = DoclingLoader(file_path=file)

docs = loader.load()
print(f"Loaded {len(docs)} documents from DoclingLoader")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from langchain_docling.loader import DoclingLoader
#       3 file = r"C:\Users\abdif\OneDrive\Documents\TaskBuddy\Syllabi\Syllabus.pdf"
#       5 loader = DoclingLoader(file_path=file)
#
# ModuleNotFoundError: No module named 'langchain_docling'

# %%
for doc in docs:
    print(doc.page_content, "\n---\n")
# Out:
# Course
# Course Title, Prefix, Number, Section: Web Technologies, CITE 30363, 074
# Semester and Year: Spring 2026
# Number of Credits: 3
# Course Component Type: Lecture
# Class Location: RJH 113
# Class Meeting Day(s) & Time(s): MW 4 PM - 5:20 PM
# ---
#
# Instructor
# Instructor Name: Bingyang Wei
# Office Location: Tucker Technology Center 341D
# Office Hours: Tuesday: 9 AM - 11 AM, Wednesday: 2 PM - 4 PM
# Preferred Method of Contact: Email
# Email: b.wei@tcu.edu
# ---
#
# FINAL EXAM: 2 PM - 4:30 PM, MAY 4, 2026
# Note for students: The syllabus is your first course reading. It provides an orientation to, overview of the flow, and expectations of the course. You should turn to the syllabus for details on assignments and course policies.
# ---
#
# Student Resources & Policy Information
# Scan QR code for resources to support you as a TCU student. Please note section on Student Access and Accommodation, Academic Conduct & Course Materials Policies, and Emergency Response & TCU Alert.
# ---
#
# SYLLABUS: WEB TECHNOLOGIES
# Last updated: January 12, 2026
# ---
#
# Catalog Description
# Prerequisite: COSC 30603 with C- or better. This course will provide an overview of the current full-stack web technologies. The students will learn both client-side and serverside technologies to create a functional dynamic web application. The course will include a  detailed  introduction  to  HTML,  CSS,  JavaScript,  and  HTTP  followed  by  in-depth coverage of server-side programming and database connectivity. Popular web frameworks will also be included. Projects will be required that demonstrate the student's understanding of these technologies.
# ---
#
# Prerequisites & Concurrent Enrollment
# Prerequisite: COSC 30603 with C- or better.
# ---
#
# Required Materials
# None.
# ---
#
# TEACHING PHILOSOPHY & METHODOLOGY
# Although the World Wide Web (WWW) was initially conceived as a vehicle for delivering documents, it is now being used as a platform for sophisticated interactive applications, displacing  the  traditional  mechanism  of  installable  binaries.  However,  creating  Web applications requires different approaches than traditional applications and involves the integration of numerous technologies. This course will provide an overview of the current full stack of web technologies and give you experience creating Web applications.
# The students will study both client-side and server-side technologies. The course will include a detailed introduction to HTML, CSS, JavaScript followed by in-depth coverage of Java based server-side development. Popular web frameworks including Bootstrap, Vue.js, and Spring Boot will be introduced.
# ---
#
# Course Learning Outcomes
# Students completing this course are expected to be able to
# - 1) describe the general architecture of web applications
# - 2) describe HTTP protocol
# - 3) create web pages using HTML, CSS, and JavaScript
# - 4) build dynamic database web application using Java based web technologies
# - 5) deploy web applications to the cloud
# - 6) be familiar with the JSON data format
# - 7) understand API-First Approach to building software products
# - 8) design RESTful APIs
# ---
#
# Assignments
# - Final exam.
# - Quizzes.
# - Homework.
# - Code-Alongs: In-class programming demo code will not be provided to you directly, instead you need to type the in-class programming demos after class and upload your code to TCU Online every week. Code-Along is a great way to learn programming, read this article first:
# https://medium.com/@ryanfleharty/conquering-the-code-along-5ebe37941f70
# ---
#
# Late Assignments
# Late assignment incurs a 15% penalty for each late day, including weekend and holidays. Assignments that are late more than TWO days will NOT be accepted (except for medical reasons).
# ---
#
# Missed In-class Activities
# If you miss, you CANNOT make it up (except for medical reasons).
# ---
#
# Missed Exams
# Make up exams will be given only for Official University Absences or absences approved in advance by the instructor. Such absences include documented medical illnesses or family emergencies.
# ---
#
# Questions on Grading
# Requests for re-evaluation of points on exams, assignments, and projects must be made to the instructor within one week of receiving your grade and accompanied by a brief written description of the grading error you believe was made. After this time, grades are final.  Resubmission  for  re-evaluation  subjects  the  entire  assignment  for  review.  This means that if an error was made in your favor, you may lose points when re-submitting.
# ---
#
# I Do Not Accept Medical Documentation
# Because it is considered an infringement on student privacy for me to have access to student medical records, I cannot accept medical documentation to justify absences. If you have a legitimate reason for your absence and want to provide verification, please access the Absence Documentation Form here.
# ---
#
# Course Assignments & Final Grade
# Final 30, Percentage or Points = . 10, Percentage or Points = Homework. Quiz 20, Percentage or Points =
# 20, Percentage or Points = Code-Along. Team Project 20, Percentage or Points = . Total, Percentage or Points = 100
# ---
#
# Grading Scale(s)
# A, Score = 90-100. B, Score = 80-89. C, Score = 70-79. D, Score = 60-69. F, Score = 0-59
# ---
#
# COURSE SCHEDULE
# This  calendar  represents  my  current  plans  and  objectives.  As  we  go  through  the semester, those plans may need to change to enhance the class learning opportunities. Such changes will be clearly communicated.
# ---
#
# COURSE SCHEDULE
# 1, Date = 01/12. 1, Topics = Syllabus; HTML. 1, Assignments = . 1, References = https://www.w3schools.com/html/ https://developer.mozilla.org/en- US/docs/Web/HTML. 2, Date = 01/19. 2, Topics = CSS. 2, Assignments = Homework assigned. 2, References = https://www.w3schools.com/css/ https://developer.mozilla.org/en- US/docs/Web/CSS. 3, Date = 01/26. 3, Topics = JavaScript Basics. 3, Assignments = . 3, References = https://www.w3schools.com/js/. 4, Date = 02/02. 4, Topics = JavaScript Advanced and Bootstrap. 4, Assignments = Homework due. 4, References = https://getbootstrap.com/. 5, Date = 02/09. 5, Topics = HTTP; AJAX & JSON; API First Approach. 5, Assignments = . 5, References =
# ---
#
# COURSE SCHEDULE
# https://www.w3schools.com/xml/aj ax_intro.asp https://www.w3schools.com/js/js_j son_intro.asp. 6, Date = 02/16. 6, Topics = Node.js. 6, Assignments = Team project assigned. 6, References = https://nodejs.org/en/docs/. 7, Date = 02/23. 7, Topics = Vue Basics. 7, Assignments = . 7, References = https://vuejs.org/. 8, Date = 03/02. 8, Topics = Vue Components. 8, Assignments = . 8, References = https://vitejs.dev/guide/. 9, Date = 03/09. 9, Topics = Spring Boot. 9, Assignments = . 9, References = https://spring.io/projects/spring- boot. 10, Date = 03/16. 10, Topics = Spring Break. 10, Assignments = No classes. 10, References = . 11, Date = 03/23. 11, Topics = Spring Boot cont.. 11,
# ---
#
# COURSE SCHEDULE
# Assignments = . 11, References = . 12, Date = 03/30. 12, Topics = Vue Router. 12, Assignments = . 12, References = https://router.vuejs.org/
# 13, Date = 04/06. 13, Topics = Vue State Management. 13, Assignments = . 13, References = https://pinia.vuejs.org/. 14, Date = 04/13. 14, Topics = Project. 14, Assignments = . 14, References = https://docs.github.com/en/actions. 15, Date = 04/20. 15, Topics = Project. 15, Assignments = . 15, References = . 16, Date = 04/27. 16, Topics = Project. 16, Assignments = Team Project due. 16, References = . 17, Date = 05/04. 17, Topics = Final exam: 2 PM - 4:30 PM, MAY 4, 2026. 17, Assignments = Final exam: 2 PM - 4:30 PM, MAY 4, 2026. 17, References = Final exam: 2 PM - 4:30 PM, MAY 4, 2026
# ---

# %%
from docling.chunking import HybridChunker

loader = DoclingLoader(
    file_path=mock_data_path,
    chunker=HybridChunker()
)

docs = loader.load()
print(f"Loaded {len(docs)} documents with HybridChunker")
# Out:
# [INFO] 2026-02-27 13:15:02,726 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 13:15:02,741 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-27 13:15:02,742 [RapidOCR] main.py:53: Using C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-27 13:15:02,847 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 13:15:02,851 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-27 13:15:02,851 [RapidOCR] main.py:53: Using C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-27 13:15:02,916 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 13:15:02,951 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2026-02-27 13:15:02,952 [RapidOCR] main.py:53: Using C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# Loaded 31 documents with HybridChunker

# %%
for doc in docs:
    print(doc.page_content, "\n---\n")
# Out:
# Kiril Kuzmin
# Spring, 2025
# Office: 25 Park Place 750, Class Hours: M,W 5:30-7:15pm = Class Room: Langdale Hall 215
# ---
#
# Course Description
# This course provides students with essential concepts, principles, and tools to extract and generalize knowledge from data. Students will develop a comprehensive skill set, including data processing, statistics, and machine learning, and gain a solid understanding of how these skills integrate to solve real-world problems. The course systematically introduces key topics in data science, including:
# 1. Principles of data processing and representation;
# 2. Theoretical foundations and recent advancements in data science;
# 3. Modeling and algorithms;
# 4. Evaluation techniques.
# The focus will be on the breadth of these topics rather than on in-depth exploration. Realworld engineering problems and datasets will be used to illustrate the advantages and limitations of various algorithms, allowing students to compare their effectiveness and efficiency and to discern the contexts in which specific algorithms are most appropriate.
# ---
#
# Subgroups
# Our class is composed of three subgroups that come together as a one large group:
# 19296, Section = CSC 4780. 19297, Section = CSC 6780. 19298, Section = DSCI 4780
# ---
#
# Week 1: Introduction to Data Science
# - Overview of data science
# - Types of learning
# - Predictive data analytics
# - Introduction to numpy for numerical computations
# ---
#
# Week 2: Data Manipulation and Analysis
# - Introduction to pandas for data manipulation and analysis
# - Problem-solving with numpy and pandas
# ---
#
# Week 3: Data Exploration and Visualization
# - Data visualization using matplotlib and seaborn
# - Exploratory data analysis
# ---
#
# Week 4: Data Preparation and Presentation
# - Data preparation techniques
# - Principles of effective data presentation and visualization
# ---
#
# Week 5: Information-Based Learning
# - Entropy, information gain, and Gini index
# - Decision trees and the ID3 algorithm
# - Successors of ID3: C4.5 and CART (Classification and Regression Trees)
# ---
#
# Week 6: Similarity-Based Learning
# - Introduction to k -NN ( k -Nearest Neighbors)
# - Midterm review
# ---
#
# Week 7: Probability-Based Learning and Midterm
# - Naive Bayes model
# - Midterm exam
# ---
#
# Week 8: Error-Based Learning
# - Linear and logistic regression
# - Introduction to SVM (Support Vector Machine) and kernels
# ---
#
# Week 9: Feature Selection and Engineering
# - Correlation analysis and mutual information
# - Encoding techniques and feature creation/extraction
# - Forward and backward feature selection
# ---
#
# Week 10: Model Evaluation and Hyperparameter Tuning
# - Metrics: Accuracy, precision, recall (sensitivity), F1-score, specificity
# - ROC (Receiver Operating Characteristic) curve and thresholding
# - Cross-validation and grid search
# ---
#
# Week 11: Unsupervised Learning
# - Clustering techniques: k -means and hierarchical clustering
# - Dendrograms and their interpretation
# ---
#
# Week 12: Ensemble Models
# - Random forest
# - BAgging (Bootstrap Aggregating) and Boosting
# - AdaBoost (Adaptive Boosting) and Gradient boosting
# ---
#
# Week 13: Neural Networks and Project Presentations
# - Fundamentals of Neural networks
# - Project presentations
# ---
#
# Week 14: Final Review and Conclusion
# - Final exam preparation
# - Project presentations
# - Course wrap-up and next steps
# ---
#
# Homeworks
# Completing all assignments independently is essential for success in this class. You must strictly adhere to the homework submission requirements provided on iCollege .
# Each submission should consist of the source code as Jupyter notebook file (with an extension ipynb ). The submissions must be uploaded on iCollege dropbox into the relevant folder.
# If the teaching assistant cannot open and read it, or if you submit a flawed document, the grade will be zero. It is your responsibility to ensure that each file opens correctly. Having submitted it on iCollege , go and try to open/download it. Make sure that you hit the 'submit' button, and get a notification from iCollege that your submission has successfully gone through.
# Your homework assignments will be checked by
# Abhiram Gaddam, Email = agaddam2@student.gsu.edu. Abhiram Gaddam, Office hours = in Webex by appointment
# ---
#
# Final Project
# The final project is a team-based endeavor aimed at applying data science concepts to a realworld problem. Teams of 4-6 members will design and implement a data analytics solution over multiple phases, culminating in a presentation and final report. The project will count for 20% of your final grade.
# ---
#
# Project Phases
# - Phase 1 Proposal: Form teams and submit a project proposal, including the problem statement, dataset(s), and analytics goals.
# - Phase 2 Business Understanding: Define the business problem and finalize the dataset and analytics solution.
# - Phase 3 Data Preparation: Explore and preprocess the data. Select features.
# - Phase 4 Modeling and Evaluation: Test at least three categories of models and perform hyperparameter optimization.
# - Phase 5 Communication: Present your findings in a 15-minute presentation and submit a final report.
# ---
#
# Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
# ---
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.
# ---
#
# Textbooks
# Course materials should be sufficient to excel in this class. However, if you prefer additional resources, I recommend the following books:
# 1. Grokking Machine Learning by Luis G. Serrano (Manning Publications Co., 2021). ISBN: 978-1617295911
# A beginner-friendly introduction to machine learning concepts with clear explanations and visual examples.
# 2. Data Science from Scratch by Joel Grus (O'Reilly Media, Inc, 2019). ISBN: 978-1492041139 Introduces data science fundamentals with Python, focusing on coding concepts from the ground up. While this book emphasizes implementation from scratch, in this class, we will primarily focus on using scikit-learn methods.
# 3. Fundamentals of Machine Learning for Predictive Data Analytics by John D. Kelleher, Brian Mac Namee, and Aoife D'Arcy (Second Edition, The MIT Press, 2015). ISBN: 9780262029445
# A practical guide to machine learning techniques, with a focus on predictive analytics and practical applications.
# ---
#
# Textbooks
# 4. An Introduction to Statistical Learning with Applications in Python by Gareth James, Daniela Witten, Trevor Hastie, Robert Tibshirani, and Jonathan Taylor (Springer, 2023). ISBN: 978-3031387463
# An accessible introduction to statistical learning, covering Python-based implementations and real-world applications.
# Books are listed in increasing order of rigor and difficulty.
# ---
#
# Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
# ---
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.
# ---
#
# Attendance
# Attendance at the lectures is not mandatory but is strongly encouraged. This class is one of the most crucial for aspiring data scientists and data analysts. We will focus on discussing and solving numerous problems frequently encountered in technical job interviews.
# ---
#
# Late Assignments
# Late assignments may be accepted for no penalty if a valid excuse is communicated to the instructor before the deadline. If you exceed the deadline for more than 1 hour, your assignment will be penalized. The penalty is a 20% deduction for each extra 24 hours after the deadline. E.g., a homework scored 83% but submitted one day late (more than 1 hour and less than 24 hours late) will only receive 63% for the grade; the same homework submitted 2 days late (more than 24 hours and less than 48 hours late) will only receive 43%, and so on. Thus, even a perfect 100%-score submission which is more that four-day-late will receive no credit (but may receive some feedback).
# ---
#
# Cheating
# Do not cheat! While discussing problems with others is allowed, coding must be done independently. If you get stuck, you may research approaches online (e.g., stackoverflow.com) or use generative AI tools (e.g., ChatGPT). However, avoid blindly copying solutions - understand them first, then close the resource and implement the solution based on your understanding and memory.
# Copying another student's work will result in severe penalties, including a grade of zero for the activity (homework/exam) for all students involved. In some cases of plagiarism, at the instructor's discretion, students may receive a failing grade for the course.
# ---
#
# Students with Special Needs
# Students requiring special accommodations are encouraged to schedule a meeting with the instructor as soon as possible. Prior to the meeting, please email your Faculty Notification Letter. Note that accommodations are not applied retroactively and will take effect only from the time they are granted.
# ---
#
# Closing of the University
# Sometimes the university closes because of weather conditions. To find out if the university is closed, go to gsu.edu or listen for an announcement on local TV or radio channels. If a class is canceled, planned activities will take place during the next class session.
# ---

# %%
full_text = "\n\n".join([doc.page_content for doc in docs])
print(f"Combined full text length: {len(full_text)} characters")
# Out:
# Combined full text length: 10703 characters

# %%
# create chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=500,
    separators=["\n\n", "\n", ". ", " ", ""]
)
chunks = text_splitter.split_text(full_text)
print(f"Created {len(chunks)} chunks")
# Out:
# Created 11 chunks

# %%
embeddings = GoogleGenerativeAIEmbeddings(
    model = "models/gemini-embedding-001",
)
vectorstore = Chroma.from_texts(
    texts=chunks,
    embedding=embeddings,
    collection_name="taskbuddy_with_docling"
)

print(f"Stored {vectorstore._collection.count()} chunks in the vector store")
# Out:
# Stored 33 chunks in the vector store

# %%
retrieval = vectorstore.similarity_search("extract every assignment, project, or exam mentioned", k=5)
for i in retrieval:
  print(i,'\n')
# Out:
# page_content='Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.'
#
# page_content='Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.'
#
# page_content='Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.'
#
# page_content='Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.'
#
# page_content='Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.'

# %%
retrieval = vectorstore.similarity_search_with_score("extract every assignment, project, or exam mentioned", k=5)
for doc, score in retrieval:
    print(f"Score: {score:.4f}\n{doc.page_content}\n")
# Out:
# Score: 0.6402
# Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.
#
# Score: 0.6402
# Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.
#
# Score: 0.6402
# Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.
#
# Score: 0.6535
# Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.
#
# Score: 0.6535
# Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.
