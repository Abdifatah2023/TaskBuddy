# %% [markdown]
# ## Connect to Google Drive Mock Data

# %%
# !pip install -q -U langchain-google-genai langchain langchain-community PyPDF2
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\owner\appdata\roaming\python\python313\site-packages (6.7.3)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\owner\appdata\roaming\python\python313\site-packages (1.3.4)
# Requirement already satisfied: build>=1.0.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (2.11.10)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (2.2.6)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\owner\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.10.5)
# Requirement already satisfied: packaging>=19.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\owner\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\owner\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx>=0.27.0->chromadb) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\owner\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.48.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\owner\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\owner\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (46.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from cryptography>=38.0.3->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\owner\appdata\roaming\python\python313\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (2.23)
# Requirement already satisfied: coloredlogs in c:\users\owner\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\owner\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\owner\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.0)
# Requirement already satisfied: sympy in c:\users\owner\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\owner\appdata\roaming\python\python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in c:\users\owner\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\owner\appdata\roaming\python\python313\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipywidgets) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\owner\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\owner\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\owner\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
import os


# 2. Define your Mock Data path (Update 'MyProjectFolder' to your actual folder name)
mock_data_path = r"G:\.shortcut-targets-by-id\1IE0kGxUTOOmWfsPivDfCtr3CiHJJR9TO\Agentic_AI_Team_Folder\mock_data\syllabus\Syllabus.pdf"

# 3. List files to verify the agent can "see" them
# files = os.listdir(mock_data_path)
# print(f"Found {len(files)} documents: {files}")

# %% [markdown]
# ## Basic AI Agent Set up

# %%
from dotenv import load_dotenv

load_dotenv()


# It's best practice to store keys in Colab "Secrets" (the key icon on the left)
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-preview-09-2025")

# %%
from langchain_community.document_loaders import PyPDFLoader

# Initialize the loader with the path to your PDF file
loader = PyPDFLoader(mock_data_path)

# Load the documents (each page is a separate Document object)
pages = loader.load()

# You can now work with the loaded pages, for example, print the number of pages
print(f"Number of pages loaded: {len(pages)}")

# Or access the content of a specific page
if pages:
    print(pages[0].page_content[:200]) # Print the first 200 characters of the first page
# Out:
# Number of pages loaded: 7
# 4780/6780: Fundamentals of Data Science
# Kiril Kuzmin
# Spring, 2025
# E-mail: kkuzmin1@gsu.edu
# Office Hours: M 2:00–4:00pm Class Hours: M,W 5:30–7:15pm
# Office: 25 Park Place 750 Class Room: Langdale Hall

# %%
full_text = "\n\n".join([page.page_content for page in pages])
print(f"Loaded {len(pages)} pages, {len(full_text)} total characters")
# Out:
# Loaded 7 pages, 11227 total characters

# %%
# create chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=500,
    separators=["\n\n", "\n", ". ", " ", ""]
)
chunks = text_splitter.split_text(full_text)
print(f"Created {len(chunks)} chunks")
# Out:
# Created 12 chunks

# %%
# embedding
embeddings = GoogleGenerativeAIEmbeddings(
    model = "models/gemini-embedding-001"
)

# Create a Chroma vector store from the chunks
vectorstore = Chroma.from_texts(
    texts=chunks,
    embedding=embeddings,
    collection_name="TaskBudy_Phase1"
)

print(f"Stored {vectorstore._collection.count()} chunks in the vector store")
# Out:
# Stored 12 chunks in the vector store

# %%
retrieval = vectorstore.similarity_search("extract every assignment, project, or exam mentioned", k=5)
for i in retrieval:
  print(i,'\n')
# Out:
# page_content='✓ Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and
# modeling.
# ✓ Presentation (30 points): Deliver a clear and professional group presentation, followed by a
# Q&A.
# ✓ Final Report (25 points): Submit a detailed PDF report explaining your process, findings,
# and recommendations.
# Deadlines
# • February 18 th: Proposal submission (via email to kkuzmin1@gsu.edu with CC to all mem-
# bers).
# • April 16 th, April 21th, April 23th: Project presentations.
# • April 25 th: Final report submission.
# Further details and guidelines will be provided on iCollege.
# 4/7'
#
# page_content='4780/6780: Fundamentals of Data Science: Spring 2025
# • Encoding techniques and feature creation/extraction
# • Forward and backward feature selection
# Week 10: Model Evaluation and Hyperparameter T uning
# • Metrics: Accuracy, precision, recall (sensitivity), F1-score, specificity
# • ROC (Receiver Operating Characteristic) curve and thresholding
# • Cross-validation and grid search
# Week 11: Unsupervised Learning
# • Clustering techniques: k-means and hierarchical clustering
# • Dendrograms and their interpretation
# Week 12: Ensemble Models
# • Random forest
# • BAgging (Bootstrap Aggregating) and Boosting
# • AdaBoost (Adaptive Boosting) and Gradient boosting
# Week 13: Neural Networks and Project Presentations
# • Fundamentals of Neural networks
# • Project presentations
# Week 14: Final Review and Conclusion
# • Final exam preparation
# • Project presentations
# • Course wrap-up and next steps
# Homeworks
# Completing all assignments independently is essential for success in this class. You must strictly
# adhere to the homework submission requirements provided on iCollege.
# Each submission should consist of the source code as Jupyter notebook file (with an extension
# ipynb). The submissions must be uploaded on iCollege dropbox into the relevant folder.
# If the teaching assistant cannot open and read it, or if you submit a flawed document, the
# grade will be zero. It is your responsibility to ensure that each file opens correctly. Having'
#
# page_content='4780/6780: Fundamentals of Data Science: Spring 2025
# The grade will count the assessments using the following proportions:
# • 30% of your grade will be based on homework assignments (5 total, with the lowest score
# dropped).
# • 20% of your grade will be based on the project (proposal due February 18 th).
# • 25% of your grade will be based on the midterm, scheduled for regular class hours on
# Wednesday, February 26th (tentative).
# • 25% of your grade will be based on the final, held during exam week in the same classroom
# on Wednesday, April 30th, 4:15–6:00pm.
# Makeup exams – midterm and final – are not given! Exceptions to this policy may be made
# only in case of a family or medical emergency, which must be clearly documented AND submit-
# ted through Professor Absence Notification system. Please note that to be eligible for makeup
# exams, your absence request must be approved by the Office of the Dean of Students.
# Attendance
# Attendance at the lectures is not mandatory but is strongly encouraged. This class is one of
# the most crucial for aspiring data scientists and data analysts. We will focus on discussing and
# solving numerous problems frequently encountered in technical job interviews.
# Late Assignments
# Late assignments may be accepted for no penalty if a valid excuse is communicated to the in-
# structor before the deadline. If you exceed the deadline for more than 1 hour, your assignment
# will be penalized. The penalty is a 20% deduction for each extra 24 hours after the deadline.'
#
# page_content='pendently. If you get stuck, you may research approaches online (e.g., stackoverflow.com) or
# use generative AI tools (e.g., ChatGPT). However, avoid blindly copying solutions – understand
# them first, then close the resource and implement the solution based on your understanding and
# memory.
# Copying another student’s work will result in severe penalties, including a grade of zero for
# the activity (homework/exam) for all students involved. In some cases of plagiarism, at the
# instructor’s discretion, students may receive a failing grade for the course.
# 6/7'
#
# page_content='adhere to the homework submission requirements provided on iCollege.
# Each submission should consist of the source code as Jupyter notebook file (with an extension
# ipynb). The submissions must be uploaded on iCollege dropbox into the relevant folder.
# If the teaching assistant cannot open and read it, or if you submit a flawed document, the
# grade will be zero. It is your responsibility to ensure that each file opens correctly. Having
# submitted it on iCollege, go and try to open/download it. Make sure that you hit the “submit”
# button, and get a notification from iCollege that your submission has successfully gone through.
# Your homework assignments will be checked by
# Name Email Office hours
# Abhiram Gaddam agaddam2@student.gsu.edu in Webex by appointment
# 3/7'

# %%
# --- Prompt and Generation ---
template = """You are an academic assistant. Below is the text from several syllabus documents.
    Please extract every assignment, project, or exam mentioned.
    Format the output as a clean table with two columns: 'Assignment Name' and 'Due Date'.
    If a due date is missing, write 'Not Specified'

Context: {context}

Question: {question}

Answer:"""

prompt = ChatPromptTemplate.from_template(template)
llm = ChatGoogleGenerativeAI(model="gemini-flash-latest")

def format_docs(docs):
    return "\n\n---\n\n".join(doc.page_content for doc in docs)

rag_chain = (
    {"context": vectorstore.as_retriever(search_kwargs={"k": 5}) | format_docs,
    "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)
print("RAG chain built successfully.")
# Out:
# RAG chain built successfully.

# %%
from IPython.display import Markdown

response = rag_chain.invoke('Generate')
display(Markdown(response))
# Out:
# Based on the syllabus documents provided, here are the assignments, projects, and exams mentioned:
#
# | Assignment Name | Due Date |
# | :--- | :--- |
# | Homework Assignments (5 total) | Not Specified |
# | Project Proposal | February 18th |
# | Midterm Exam | February 26th (tentative) |
# | Project Presentations | April 16th, April 21st, or April 23rd |
# | Final Project Report | April 25th |
# | Final Exam | April 30th (4:15–6:00pm) |
# | Project Implementation (Jupyter notebooks) | Not Specified |

# %% [markdown]
# will need to rewrite the function below and combine it with the retrieval above

# %%
# def extract_assignments():
#     raw_content = pages[0].page_content

#     prompt = f"""
#     You are an academic assistant. Below is the text from several syllabus documents.
#     Please extract every assignment, project, or exam mentioned.
#     Format the output as a clean table with two columns: 'Assignment Name' and 'Due Date'.
#     If a due date is missing, write 'Not Specified'.

#     SYLLABUS TEXT:
#     {raw_content}
#     """

#     response = llm.invoke(prompt)
#     return response.content

# # Run the agent
# assignments_list = extract_assignments()
# print(assignments_list)

# %% [markdown]
# ## Google Calendar

# %%
# %pip install -qU langchain-google-community\[calendar\]
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\requirements.py", line 36, in __init__
#     parsed = _parse_requirement(requirement_string)
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_parser.py", line 62, in parse_requirement
#     return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_parser.py", line 77, in _parse_requirement
#     extras = _parse_extras(tokenizer)
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_parser.py", line 164, in _parse_extras
#     with tokenizer.enclosing_tokens(
#          ~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         "LEFT_BRACKET",
#         ^^^^^^^^^^^^^^^
#         "RIGHT_BRACKET",
#         ^^^^^^^^^^^^^^^^
#         around="extras",
#         ^^^^^^^^^^^^^^^^
#     ):
#     ^
#   File "c:\python313\Lib\contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_tokenizer.py", line 190, in enclosing_tokens
#     self.raise_syntax_error(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         f"Expected matching {close_token} for {open_token}, after {around}",
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         span_start=open_position,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\_tokenizer.py", line 168, in raise_syntax_error
#     raise ParserSyntaxError(
#     ...<3 lines>...
#     )
# pip._vendor.packaging._tokenizer.ParserSyntaxError: Expected matching RIGHT_BRACKET for LEFT_BRACKET, after extras
#     placeholder[calendar\]
#                ~~~~~~~~~^
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\base_command.py", line 107, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\base_command.py", line 98, in _inner_run
#     return self.run(options, args)
#            ~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\req_command.py", line 85, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_internal\commands\install.py", line 354, in run
#     reqs = self.get_requirements(args, options, finder, session)
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_internal\cli\req_command.py", line 264, in get_requirements
#     req_to_add = install_req_from_line(
#         req,
#     ...<3 lines>...
#         config_settings=getattr(options, "config_settings", None),
#     )
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_internal\req\constructors.py", line 427, in install_req_from_line
#     parts = parse_req_from_line(name, line_source)
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_internal\req\constructors.py", line 377, in parse_req_from_line
#     extras = convert_extras(extras_as_string)
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_internal\req\constructors.py", line 61, in convert_extras
#     return get_requirement("placeholder" + extras.lower()).extras
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_internal\utils\packaging.py", line 44, in get_requirement
#     return Requirement(req_string)
#   File "C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\packaging\requirements.py", line 38, in __init__
#     raise InvalidRequirement(str(e)) from e
# pip._vendor.packaging.requirements.InvalidRequirement: Expected matching RIGHT_BRACKET for LEFT_BRACKET, after extras
#     placeholder[calendar\]
#                ~~~~~~~~~^

# %%
# %pip install google-auth-oauthlib
# Out:
# Requirement already satisfied: google-auth-oauthlib in c:\users\owner\appdata\roaming\python\python313\site-packages (1.2.4)
# Requirement already satisfied: google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth-oauthlib) (2.48.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (46.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.6.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\owner\appdata\roaming\python\python313\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (2.23)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import datetime
import zoneinfo
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

SCOPES = ["https://www.googleapis.com/auth/calendar.events"]


def event_exists(service, title, start_time, end_time):
    """Check if an event with same title exists in the time window"""
    events_result = service.events().list(
        calendarId="primary",
        timeMin=start_time,
        timeMax=end_time,
        singleEvents=True,
        orderBy="startTime"
    ).execute()




    events = events_result.get("items", [])

    for e in events:
        if e.get("summary") == title:
            return True

    return False



def main():
    creds = None

    if os.path.exists("token.json"):
        creds = Credentials.from_authorized_user_file("token.json", SCOPES)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                "credentials.json", SCOPES
            )
            creds = flow.run_local_server(port=0)

        with open("token.json", "w") as token:
            token.write(creds.to_json())





    try:
        service = build("calendar", "v3", credentials=creds)

        title = "Cloud Study Session"

        tz = zoneinfo.ZoneInfo("America/Chicago")

        start_dt = datetime.datetime(2026, 2, 28, 15, 0, 0, tzinfo=tz)
        end_dt = datetime.datetime(2026, 2, 28, 17, 0, 0, tzinfo=tz)

        start_iso = start_dt.isoformat()
        end_iso = end_dt.isoformat()
        
        if event_exists(service, title, start_iso, end_iso):
            print("event already exists!")
            return
        
        # 🔥 Event details
        event = {
            "summary": title,
            "location": "TCU Library",
            "description": "Preparing for cloud + cybersecurity internship",
            "start": {
                "dateTime": start_iso,
                "timeZone": "America/Chicago",
            },
            "end": {
                "dateTime": end_iso,
                "timeZone": "America/Chicago",
            },
            "reminders": {
                "useDefault": False,
                "overrides": [
                    {"method": "popup", "minutes": 30},
                    {"method": "popup", "minutes": 10},
                ],
            }
        }

        created_event = service.events().insert(
            calendarId="primary",
            body=event
        ).execute()

        print("Event created:", created_event.get("htmlLink"))

    except HttpError as error:
        print(f"An error occurred: {error}")

if __name__ == "__main__":
    main()
# Out:
# event already exists!

# %% [markdown]
# ## Docling - doc parser

# %%
# %pip install docling torch torchvision
# Out:
# Requirement already satisfied: docling in c:\users\owner\appdata\roaming\python\python313\site-packages (2.75.0)
# Requirement already satisfied: torch in c:\users\owner\appdata\roaming\python\python313\site-packages (2.10.0)
# Requirement already satisfied: torchvision in c:\users\owner\appdata\roaming\python\python313\site-packages (0.25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (2.11.10)
# Requirement already satisfied: docling-core<3.0.0,>=2.62.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core[chunking]<3.0.0,>=2.62.0->docling) (2.66.0)
# Requirement already satisfied: docling-parse<6.0.0,>=5.3.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (5.4.0)
# Requirement already satisfied: docling-ibm-models<4,>=3.9.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (3.11.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (1.2.0)
# Requirement already satisfied: pypdfium2!=4.30.1,<6.0.0,>=4.30.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (5.5.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (2.11.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (0.36.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (2.32.5)
# Requirement already satisfied: rapidocr<4.0.0,>=3.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (3.6.0)
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (2025.10.5)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (1.4.1)
# Requirement already satisfied: typer<0.22.0,>=0.12.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (0.20.0)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (1.2.0)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (1.0.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (4.14.2)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (2.3.0)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (2.2.2)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (3.1.5)
# Requirement already satisfied: lxml<7.0.0,>=4.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (6.0.2)
# Requirement already satisfied: pillow<13.0.0,>=10.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (11.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (4.67.1)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (1.6.0)
# Requirement already satisfied: pylatexenc<3.0,>=2.10 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (2.10)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (1.16.3)
# Requirement already satisfied: accelerate<2,>=1.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (1.12.0)
# Requirement already satisfied: polyfactory>=2.22.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (3.3.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling) (0.7.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\owner\appdata\roaming\python\python313\site-packages (from accelerate<2,>=1.0.0->docling) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from accelerate<2,>=1.0.0->docling) (25.0)
# Requirement already satisfied: psutil in c:\users\owner\appdata\roaming\python\python313\site-packages (from accelerate<2,>=1.0.0->docling) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\owner\appdata\roaming\python\python313\site-packages (from accelerate<2,>=1.0.0->docling) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from accelerate<2,>=1.0.0->docling) (0.6.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (4.15.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (4.25.1)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (1.1.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.9.0)
# Requirement already satisfied: latex2mathml<4.0.0,>=3.77.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (3.78.1)
# Requirement already satisfied: semchunk<3.0.0,>=2.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core[chunking]<3.0.0,>=2.62.0->docling) (2.2.2)
# Requirement already satisfied: tree-sitter<0.27.0,>=0.25.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.25.2)
# Requirement already satisfied: tree-sitter-python>=0.23.6 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.25.0)
# Requirement already satisfied: tree-sitter-c>=0.23.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.24.1)
# Requirement already satisfied: tree-sitter-javascript>=0.23.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.25.0)
# Requirement already satisfied: tree-sitter-typescript>=0.23.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.23.2)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-core[chunking]<3.0.0,>=2.62.0->docling) (4.57.1)
# Requirement already satisfied: jsonlines<5.0.0,>=3.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-ibm-models<4,>=3.9.1->docling) (4.0.0)
# Requirement already satisfied: filelock in c:\users\owner\appdata\roaming\python\python313\site-packages (from torch) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\owner\appdata\roaming\python\python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\owner\appdata\roaming\python\python313\site-packages (from torch) (80.9.0)
# Requirement already satisfied: pywin32>=305 in c:\users\owner\appdata\roaming\python\python313\site-packages (from docling-parse<6.0.0,>=5.3.2->docling) (310)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonlines<5.0.0,>=3.1.0->docling-ibm-models<4,>=3.9.1->docling) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.62.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.28.0)
# Requirement already satisfied: et-xmlfile in c:\users\owner\appdata\roaming\python\python313\site-packages (from openpyxl<4.0.0,>=3.1.5->docling) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from pydantic-settings<3.0.0,>=2.3.0->docling) (1.2.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\owner\appdata\roaming\python\python313\site-packages (from python-pptx<2.0.0,>=1.0.2->docling) (3.2.9)
# Requirement already satisfied: pyclipper>=1.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rapidocr<4.0.0,>=3.3->docling) (1.4.0)
# Requirement already satisfied: opencv_python>=4.5.1.48 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rapidocr<4.0.0,>=3.3->docling) (4.12.0.88)
# Requirement already satisfied: six>=1.15.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rapidocr<4.0.0,>=3.3->docling) (1.17.0)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rapidocr<4.0.0,>=3.3->docling) (2.1.2)
# Requirement already satisfied: omegaconf in c:\users\owner\appdata\roaming\python\python313\site-packages (from rapidocr<4.0.0,>=3.3->docling) (2.3.0)
# Requirement already satisfied: colorlog in c:\users\owner\appdata\roaming\python\python313\site-packages (from rapidocr<4.0.0,>=3.3->docling) (6.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.2->docling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.2->docling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.32.2->docling) (2.3.0)
# Requirement already satisfied: mpire[dill] in c:\users\owner\appdata\roaming\python\python313\site-packages (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (2.10.2)
# Requirement already satisfied: colorama in c:\users\owner\appdata\roaming\python\python313\site-packages (from tqdm<5.0.0,>=4.65.0->docling) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\owner\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.22.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from typer<0.22.0,>=0.12.5->docling) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from typer<0.22.0,>=0.12.5->docling) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from typer<0.22.0,>=0.12.5->docling) (14.2.0)
# Requirement already satisfied: faker>=5.0.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from polyfactory>=2.22.2->docling) (40.5.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer<0.22.0,>=0.12.5->docling) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer<0.22.0,>=0.12.5->docling) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\owner\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.22.0,>=0.12.5->docling) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: multiprocess>=0.70.15 in c:\users\owner\appdata\roaming\python\python313\site-packages (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.70.18)
# Requirement already satisfied: dill>=0.4.0 in c:\users\owner\appdata\roaming\python\python313\site-packages (from multiprocess>=0.70.15->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.62.0->docling) (0.4.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\owner\appdata\roaming\python\python313\site-packages (from omegaconf->rapidocr<4.0.0,>=3.3->docling) (4.9.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install -qU langchain-docling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_docling.loader import DoclingLoader

file = r"G:\.shortcut-targets-by-id\1IE0kGxUTOOmWfsPivDfCtr3CiHJJR9TO\Agentic_AI_Team_Folder\mock_data\syllabus\Syllabus2.pdf"

loader = DoclingLoader(file_path=file)

docs = loader.load()
print(f"Loaded {len(docs)} documents from DoclingLoader")
# Out:
# [INFO] 2026-02-27 13:14:37,150 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 13:14:37,163 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-27 13:14:37,164 [RapidOCR] main.py:53: Using C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-27 13:14:37,261 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 13:14:37,264 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-27 13:14:37,265 [RapidOCR] main.py:53: Using C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-27 13:14:37,330 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 13:14:37,363 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2026-02-27 13:14:37,364 [RapidOCR] main.py:53: Using C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# Token indices sequence length is longer than the specified maximum sequence length for this model (554 > 512). Running this sequence through the model will result in indexing errors
# Loaded 22 documents from DoclingLoader

# %%
for doc in docs:
    print(doc.page_content, "\n---\n")
# Out:
# Course
# Course Title, Prefix, Number, Section: Web Technologies, CITE 30363, 074
# Semester and Year: Spring 2026
# Number of Credits: 3
# Course Component Type: Lecture
# Class Location: RJH 113
# Class Meeting Day(s) & Time(s): MW 4 PM - 5:20 PM
# ---
#
# Instructor
# Instructor Name: Bingyang Wei
# Office Location: Tucker Technology Center 341D
# Office Hours: Tuesday: 9 AM - 11 AM, Wednesday: 2 PM - 4 PM
# Preferred Method of Contact: Email
# Email: b.wei@tcu.edu
# ---
#
# FINAL EXAM: 2 PM - 4:30 PM, MAY 4, 2026
# Note for students: The syllabus is your first course reading. It provides an orientation to, overview of the flow, and expectations of the course. You should turn to the syllabus for details on assignments and course policies.
# ---
#
# Student Resources & Policy Information
# Scan QR code for resources to support you as a TCU student. Please note section on Student Access and Accommodation, Academic Conduct & Course Materials Policies, and Emergency Response & TCU Alert.
# ---
#
# SYLLABUS: WEB TECHNOLOGIES
# Last updated: January 12, 2026
# ---
#
# Catalog Description
# Prerequisite: COSC 30603 with C- or better. This course will provide an overview of the current full-stack web technologies. The students will learn both client-side and serverside technologies to create a functional dynamic web application. The course will include a  detailed  introduction  to  HTML,  CSS,  JavaScript,  and  HTTP  followed  by  in-depth coverage of server-side programming and database connectivity. Popular web frameworks will also be included. Projects will be required that demonstrate the student's understanding of these technologies.
# ---
#
# Prerequisites & Concurrent Enrollment
# Prerequisite: COSC 30603 with C- or better.
# ---
#
# Required Materials
# None.
# ---
#
# TEACHING PHILOSOPHY & METHODOLOGY
# Although the World Wide Web (WWW) was initially conceived as a vehicle for delivering documents, it is now being used as a platform for sophisticated interactive applications, displacing  the  traditional  mechanism  of  installable  binaries.  However,  creating  Web applications requires different approaches than traditional applications and involves the integration of numerous technologies. This course will provide an overview of the current full stack of web technologies and give you experience creating Web applications.
# The students will study both client-side and server-side technologies. The course will include a detailed introduction to HTML, CSS, JavaScript followed by in-depth coverage of Java based server-side development. Popular web frameworks including Bootstrap, Vue.js, and Spring Boot will be introduced.
# ---
#
# Course Learning Outcomes
# Students completing this course are expected to be able to
# - 1) describe the general architecture of web applications
# - 2) describe HTTP protocol
# - 3) create web pages using HTML, CSS, and JavaScript
# - 4) build dynamic database web application using Java based web technologies
# - 5) deploy web applications to the cloud
# - 6) be familiar with the JSON data format
# - 7) understand API-First Approach to building software products
# - 8) design RESTful APIs
# ---
#
# Assignments
# - Final exam.
# - Quizzes.
# - Homework.
# - Code-Alongs: In-class programming demo code will not be provided to you directly, instead you need to type the in-class programming demos after class and upload your code to TCU Online every week. Code-Along is a great way to learn programming, read this article first:
# https://medium.com/@ryanfleharty/conquering-the-code-along-5ebe37941f70
# ---
#
# Late Assignments
# Late assignment incurs a 15% penalty for each late day, including weekend and holidays. Assignments that are late more than TWO days will NOT be accepted (except for medical reasons).
# ---
#
# Missed In-class Activities
# If you miss, you CANNOT make it up (except for medical reasons).
# ---
#
# Missed Exams
# Make up exams will be given only for Official University Absences or absences approved in advance by the instructor. Such absences include documented medical illnesses or family emergencies.
# ---
#
# Questions on Grading
# Requests for re-evaluation of points on exams, assignments, and projects must be made to the instructor within one week of receiving your grade and accompanied by a brief written description of the grading error you believe was made. After this time, grades are final.  Resubmission  for  re-evaluation  subjects  the  entire  assignment  for  review.  This means that if an error was made in your favor, you may lose points when re-submitting.
# ---
#
# I Do Not Accept Medical Documentation
# Because it is considered an infringement on student privacy for me to have access to student medical records, I cannot accept medical documentation to justify absences. If you have a legitimate reason for your absence and want to provide verification, please access the Absence Documentation Form here.
# ---
#
# Course Assignments & Final Grade
# Final 30, Percentage or Points = . 10, Percentage or Points = Homework. Quiz 20, Percentage or Points =
# 20, Percentage or Points = Code-Along. Team Project 20, Percentage or Points = . Total, Percentage or Points = 100
# ---
#
# Grading Scale(s)
# A, Score = 90-100. B, Score = 80-89. C, Score = 70-79. D, Score = 60-69. F, Score = 0-59
# ---
#
# COURSE SCHEDULE
# This  calendar  represents  my  current  plans  and  objectives.  As  we  go  through  the semester, those plans may need to change to enhance the class learning opportunities. Such changes will be clearly communicated.
# ---
#
# COURSE SCHEDULE
# 1, Date = 01/12. 1, Topics = Syllabus; HTML. 1, Assignments = . 1, References = https://www.w3schools.com/html/ https://developer.mozilla.org/en- US/docs/Web/HTML. 2, Date = 01/19. 2, Topics = CSS. 2, Assignments = Homework assigned. 2, References = https://www.w3schools.com/css/ https://developer.mozilla.org/en- US/docs/Web/CSS. 3, Date = 01/26. 3, Topics = JavaScript Basics. 3, Assignments = . 3, References = https://www.w3schools.com/js/. 4, Date = 02/02. 4, Topics = JavaScript Advanced and Bootstrap. 4, Assignments = Homework due. 4, References = https://getbootstrap.com/. 5, Date = 02/09. 5, Topics = HTTP; AJAX & JSON; API First Approach. 5, Assignments = . 5, References =
# ---
#
# COURSE SCHEDULE
# https://www.w3schools.com/xml/aj ax_intro.asp https://www.w3schools.com/js/js_j son_intro.asp. 6, Date = 02/16. 6, Topics = Node.js. 6, Assignments = Team project assigned. 6, References = https://nodejs.org/en/docs/. 7, Date = 02/23. 7, Topics = Vue Basics. 7, Assignments = . 7, References = https://vuejs.org/. 8, Date = 03/02. 8, Topics = Vue Components. 8, Assignments = . 8, References = https://vitejs.dev/guide/. 9, Date = 03/09. 9, Topics = Spring Boot. 9, Assignments = . 9, References = https://spring.io/projects/spring- boot. 10, Date = 03/16. 10, Topics = Spring Break. 10, Assignments = No classes. 10, References = . 11, Date = 03/23. 11, Topics = Spring Boot cont.. 11,
# ---
#
# COURSE SCHEDULE
# Assignments = . 11, References = . 12, Date = 03/30. 12, Topics = Vue Router. 12, Assignments = . 12, References = https://router.vuejs.org/
# 13, Date = 04/06. 13, Topics = Vue State Management. 13, Assignments = . 13, References = https://pinia.vuejs.org/. 14, Date = 04/13. 14, Topics = Project. 14, Assignments = . 14, References = https://docs.github.com/en/actions. 15, Date = 04/20. 15, Topics = Project. 15, Assignments = . 15, References = . 16, Date = 04/27. 16, Topics = Project. 16, Assignments = Team Project due. 16, References = . 17, Date = 05/04. 17, Topics = Final exam: 2 PM - 4:30 PM, MAY 4, 2026. 17, Assignments = Final exam: 2 PM - 4:30 PM, MAY 4, 2026. 17, References = Final exam: 2 PM - 4:30 PM, MAY 4, 2026
# ---

# %%
from docling.chunking import HybridChunker

loader = DoclingLoader(
    file_path=mock_data_path,
    chunker=HybridChunker()
)

docs = loader.load()
print(f"Loaded {len(docs)} documents with HybridChunker")
# Out:
# [INFO] 2026-02-27 13:15:02,726 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 13:15:02,741 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-27 13:15:02,742 [RapidOCR] main.py:53: Using C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-02-27 13:15:02,847 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 13:15:02,851 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-27 13:15:02,851 [RapidOCR] main.py:53: Using C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2026-02-27 13:15:02,916 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-02-27 13:15:02,951 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2026-02-27 13:15:02,952 [RapidOCR] main.py:53: Using C:\Users\Owner\AppData\Roaming\Python\Python313\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# Loaded 31 documents with HybridChunker

# %%
for doc in docs:
    print(doc.page_content, "\n---\n")
# Out:
# Kiril Kuzmin
# Spring, 2025
# Office: 25 Park Place 750, Class Hours: M,W 5:30-7:15pm = Class Room: Langdale Hall 215
# ---
#
# Course Description
# This course provides students with essential concepts, principles, and tools to extract and generalize knowledge from data. Students will develop a comprehensive skill set, including data processing, statistics, and machine learning, and gain a solid understanding of how these skills integrate to solve real-world problems. The course systematically introduces key topics in data science, including:
# 1. Principles of data processing and representation;
# 2. Theoretical foundations and recent advancements in data science;
# 3. Modeling and algorithms;
# 4. Evaluation techniques.
# The focus will be on the breadth of these topics rather than on in-depth exploration. Realworld engineering problems and datasets will be used to illustrate the advantages and limitations of various algorithms, allowing students to compare their effectiveness and efficiency and to discern the contexts in which specific algorithms are most appropriate.
# ---
#
# Subgroups
# Our class is composed of three subgroups that come together as a one large group:
# 19296, Section = CSC 4780. 19297, Section = CSC 6780. 19298, Section = DSCI 4780
# ---
#
# Week 1: Introduction to Data Science
# - Overview of data science
# - Types of learning
# - Predictive data analytics
# - Introduction to numpy for numerical computations
# ---
#
# Week 2: Data Manipulation and Analysis
# - Introduction to pandas for data manipulation and analysis
# - Problem-solving with numpy and pandas
# ---
#
# Week 3: Data Exploration and Visualization
# - Data visualization using matplotlib and seaborn
# - Exploratory data analysis
# ---
#
# Week 4: Data Preparation and Presentation
# - Data preparation techniques
# - Principles of effective data presentation and visualization
# ---
#
# Week 5: Information-Based Learning
# - Entropy, information gain, and Gini index
# - Decision trees and the ID3 algorithm
# - Successors of ID3: C4.5 and CART (Classification and Regression Trees)
# ---
#
# Week 6: Similarity-Based Learning
# - Introduction to k -NN ( k -Nearest Neighbors)
# - Midterm review
# ---
#
# Week 7: Probability-Based Learning and Midterm
# - Naive Bayes model
# - Midterm exam
# ---
#
# Week 8: Error-Based Learning
# - Linear and logistic regression
# - Introduction to SVM (Support Vector Machine) and kernels
# ---
#
# Week 9: Feature Selection and Engineering
# - Correlation analysis and mutual information
# - Encoding techniques and feature creation/extraction
# - Forward and backward feature selection
# ---
#
# Week 10: Model Evaluation and Hyperparameter Tuning
# - Metrics: Accuracy, precision, recall (sensitivity), F1-score, specificity
# - ROC (Receiver Operating Characteristic) curve and thresholding
# - Cross-validation and grid search
# ---
#
# Week 11: Unsupervised Learning
# - Clustering techniques: k -means and hierarchical clustering
# - Dendrograms and their interpretation
# ---
#
# Week 12: Ensemble Models
# - Random forest
# - BAgging (Bootstrap Aggregating) and Boosting
# - AdaBoost (Adaptive Boosting) and Gradient boosting
# ---
#
# Week 13: Neural Networks and Project Presentations
# - Fundamentals of Neural networks
# - Project presentations
# ---
#
# Week 14: Final Review and Conclusion
# - Final exam preparation
# - Project presentations
# - Course wrap-up and next steps
# ---
#
# Homeworks
# Completing all assignments independently is essential for success in this class. You must strictly adhere to the homework submission requirements provided on iCollege .
# Each submission should consist of the source code as Jupyter notebook file (with an extension ipynb ). The submissions must be uploaded on iCollege dropbox into the relevant folder.
# If the teaching assistant cannot open and read it, or if you submit a flawed document, the grade will be zero. It is your responsibility to ensure that each file opens correctly. Having submitted it on iCollege , go and try to open/download it. Make sure that you hit the 'submit' button, and get a notification from iCollege that your submission has successfully gone through.
# Your homework assignments will be checked by
# Abhiram Gaddam, Email = agaddam2@student.gsu.edu. Abhiram Gaddam, Office hours = in Webex by appointment
# ---
#
# Final Project
# The final project is a team-based endeavor aimed at applying data science concepts to a realworld problem. Teams of 4-6 members will design and implement a data analytics solution over multiple phases, culminating in a presentation and final report. The project will count for 20% of your final grade.
# ---
#
# Project Phases
# - Phase 1 Proposal: Form teams and submit a project proposal, including the problem statement, dataset(s), and analytics goals.
# - Phase 2 Business Understanding: Define the business problem and finalize the dataset and analytics solution.
# - Phase 3 Data Preparation: Explore and preprocess the data. Select features.
# - Phase 4 Modeling and Evaluation: Test at least three categories of models and perform hyperparameter optimization.
# - Phase 5 Communication: Present your findings in a 15-minute presentation and submit a final report.
# ---
#
# Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
# ---
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.
# ---
#
# Textbooks
# Course materials should be sufficient to excel in this class. However, if you prefer additional resources, I recommend the following books:
# 1. Grokking Machine Learning by Luis G. Serrano (Manning Publications Co., 2021). ISBN: 978-1617295911
# A beginner-friendly introduction to machine learning concepts with clear explanations and visual examples.
# 2. Data Science from Scratch by Joel Grus (O'Reilly Media, Inc, 2019). ISBN: 978-1492041139 Introduces data science fundamentals with Python, focusing on coding concepts from the ground up. While this book emphasizes implementation from scratch, in this class, we will primarily focus on using scikit-learn methods.
# 3. Fundamentals of Machine Learning for Predictive Data Analytics by John D. Kelleher, Brian Mac Namee, and Aoife D'Arcy (Second Edition, The MIT Press, 2015). ISBN: 9780262029445
# A practical guide to machine learning techniques, with a focus on predictive analytics and practical applications.
# ---
#
# Textbooks
# 4. An Introduction to Statistical Learning with Applications in Python by Gareth James, Daniela Witten, Trevor Hastie, Robert Tibshirani, and Jonathan Taylor (Springer, 2023). ISBN: 978-3031387463
# An accessible introduction to statistical learning, covering Python-based implementations and real-world applications.
# Books are listed in increasing order of rigor and difficulty.
# ---
#
# Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
# ---
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.
# ---
#
# Attendance
# Attendance at the lectures is not mandatory but is strongly encouraged. This class is one of the most crucial for aspiring data scientists and data analysts. We will focus on discussing and solving numerous problems frequently encountered in technical job interviews.
# ---
#
# Late Assignments
# Late assignments may be accepted for no penalty if a valid excuse is communicated to the instructor before the deadline. If you exceed the deadline for more than 1 hour, your assignment will be penalized. The penalty is a 20% deduction for each extra 24 hours after the deadline. E.g., a homework scored 83% but submitted one day late (more than 1 hour and less than 24 hours late) will only receive 63% for the grade; the same homework submitted 2 days late (more than 24 hours and less than 48 hours late) will only receive 43%, and so on. Thus, even a perfect 100%-score submission which is more that four-day-late will receive no credit (but may receive some feedback).
# ---
#
# Cheating
# Do not cheat! While discussing problems with others is allowed, coding must be done independently. If you get stuck, you may research approaches online (e.g., stackoverflow.com) or use generative AI tools (e.g., ChatGPT). However, avoid blindly copying solutions - understand them first, then close the resource and implement the solution based on your understanding and memory.
# Copying another student's work will result in severe penalties, including a grade of zero for the activity (homework/exam) for all students involved. In some cases of plagiarism, at the instructor's discretion, students may receive a failing grade for the course.
# ---
#
# Students with Special Needs
# Students requiring special accommodations are encouraged to schedule a meeting with the instructor as soon as possible. Prior to the meeting, please email your Faculty Notification Letter. Note that accommodations are not applied retroactively and will take effect only from the time they are granted.
# ---
#
# Closing of the University
# Sometimes the university closes because of weather conditions. To find out if the university is closed, go to gsu.edu or listen for an announcement on local TV or radio channels. If a class is canceled, planned activities will take place during the next class session.
# ---

# %%
full_text = "\n\n".join([doc.page_content for doc in docs])
print(f"Combined full text length: {len(full_text)} characters")
# Out:
# Combined full text length: 10703 characters

# %%
# create chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=500,
    separators=["\n\n", "\n", ". ", " ", ""]
)
chunks = text_splitter.split_text(full_text)
print(f"Created {len(chunks)} chunks")
# Out:
# Created 11 chunks

# %%
embeddings = GoogleGenerativeAIEmbeddings(
    model = "models/gemini-embedding-001",
)
vectorstore = Chroma.from_texts(
    texts=chunks,
    embedding=embeddings,
    collection_name="taskbuddy_with_docling"
)

print(f"Stored {vectorstore._collection.count()} chunks in the vector store")
# Out:
# Stored 33 chunks in the vector store

# %%
retrieval = vectorstore.similarity_search("extract every assignment, project, or exam mentioned", k=5)
for i in retrieval:
  print(i,'\n')
# Out:
# page_content='Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.'
#
# page_content='Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.'
#
# page_content='Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.'
#
# page_content='Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.'
#
# page_content='Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.'

# %%
retrieval = vectorstore.similarity_search_with_score("extract every assignment, project, or exam mentioned", k=5)
for doc, score in retrieval:
    print(f"Score: {score:.4f}\n{doc.page_content}\n")
# Out:
# Score: 0.6402
# Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.
#
# Score: 0.6402
# Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.
#
# Score: 0.6402
# Deliverables and Grading
# - Processed Datasets (10 points): Submit raw and preprocessed datasets.
# - Project Implementation (35 points): Provide Jupyter notebooks for data preprocessing and modeling.
# - Presentation (30 points): Deliver a clear and professional group presentation, followed by a Q&A.
# - Final Report (25 points): Submit a detailed PDF report explaining your process, findings, and recommendations.
#
# Deadlines
# - February 18 th : Proposal submission (via email to kkuzmin1@gsu.edu with CC to all members).
# - April 16 th , April 21 th , April 23 th : Project presentations.
# - April 25 th : Final report submission.
# Further details and guidelines will be provided on iCollege.
#
# Score: 0.6535
# Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.
#
# Score: 0.6535
# Prerequisites
# - You are expected to have taken 2510 Theoretical Foundations of Computer Science and 2720 Data Structures, and received a grade of C or higher in both classes.
# - Basic knowledge of probability, algebra, and calculus is required.
# - Programming in at least one programming language. Preferably in Python 3, since all examples in lectures and all homeworks will be given with expectation of some knowledge of Python 3.
#
# Grading
# The typical GSU grading scale will be used:
# Curving is left at the instructor's discretion and is (very) unlikely to happen.
# The grade will count the assessments using the following proportions:
# - 30% of your grade will be based on homework assignments (5 total, with the lowest score dropped).
# - 20% of your grade will be based on the project (proposal due February 18 th ).
# - 25% of your grade will be based on the midterm, scheduled for regular class hours on Wednesday, February 26 th (tentative).
# - 25% of your grade will be based on the final, held during exam week in the same classroom on Wednesday, April 30 th , 4:15-6:00pm.
# Makeup exams - midterm and final - are not given! Exceptions to this policy may be made only in case of a family or medical emergency, which must be clearly documented AND submitted through Professor Absence Notification system. Please note that to be eligible for makeup exams, your absence request must be approved by the Office of the Dean of Students.
